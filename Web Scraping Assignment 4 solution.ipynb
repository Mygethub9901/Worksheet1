# %%
# !pip install selenium

# %% [markdown]
# install the selenium driver

# %%
import selenium
import pandas as pd
from selenium import webdriver

# %%
import selenium
import pandas as pd
import time
from bs4 import BeautifulSoup

# Importing selenium webdriver 
from selenium import webdriver

# Importing required Exceptions which needs to handled
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException

#Importing requests
import requests

# importing regex
import re

# %% [markdown]
# import files and driver

# %% [markdown]
# 1. Scrape the details of most viewed videos on YouTube from Wikipedia:
# Url = https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos/
# You need to find following details:
# A) Rank
# B) Name
# C) Artist
# D) Upload date
# E) Views

# %%
driver = webdriver.Chrome(r"C:\Users\Ankita\Downloads\chromedriver_win32\chromedriver.exe")
time.sleep(2)

url = "https://en.wikipedia.org/wiki/List_of_most-viewed_YouTube_videos"
driver.get(url)
time.sleep(2)

# %% [markdown]
# call chrome driver link and youtube link of most viewed videos

# %%
time.sleep(4)
# creating empty lists for scraping data
Video_Rank=[]
video_Name=[]
Artist_Name=[]
Upload_date=[]
Video_Views=[]

# %% [markdown]
# Dataframes of all the variables

# %%
#Name=driver.find_elements_by_xpath("//a[@class='mw-redirect']")
Name=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//td[2]")
for i in Name:
    if i.text is None :
        video_Name.append("--") 
    else:
        video_Name.append(i.text)
        
time.sleep(4)
#scraping the job-location
Artist=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//td[3]")
for i in Artist:
    if i.text is None :
        Artist_Name.append("--") 
    else:
        Artist_Name.append(i.text)
        
time.sleep(4)        
Views=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//td[4]")
for i in Views:
    if i.text is None :
        Video_Views.append("--") 
    else:
        Video_Views.append(i.text)
        
time.sleep(4)        
Date=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//td[5]")
for i in Date:
    if i.text is None :
        Upload_date.append("--") 
    else:
        Upload_date.append(i.text)
        
time.sleep(4)        
Rank=driver.find_elements_by_xpath("//table[@class='wikitable sortable jquery-tablesorter']//td[6]")
for i in Rank:
    if i.text is None :
        Video_Rank.append("--") 
    else:
        Video_Rank.append(i.text)

# %% [markdown]
# Scrap the information and URLs of Rank, Name, Artist, Date, Views link.

# %%
video_Name=[]
for i in Name[0:30]:
    video_Name.append(i.text)
video_Name
# Out:
# ['"Baby Shark Dance"[22]',
#  '"Despacito"[24]',
#  '"Johny Johny Yes Papa"[25]',
#  '"Shape of You"[26]',
#  '"See You Again"[27]',
#  '"Bath Song"[30]',
#  '"Learning Colors – Colorful Eggs on a Farm"[31]',
#  '"Masha and the Bear – Recipe for Disaster"[32]',
#  '"Uptown Funk"[33]',
#  '"Gangnam Style"[34]',
#  '"Phonics Song with Two Words"[36]',
#  '"Dame Tu Cosita"[37]',
#  '"Sugar"[38]',
#  '"Sorry"[39]',
#  '"Roar"[40]',
#  '"Counting Stars"[41]',
#  '"Thinking Out Loud"[42]',
#  '"Wheels on the Bus"[43]',
#  '"Dark Horse"[44]',
#  '"Faded"[45]',
#  '"Girls Like You"[46]',
#  '"Shake It Off"[47]',
#  '"Lean On"[48]',
#  '"Bailando"[49]',
#  '"Let Her Go"[50]',
#  '"Mi Gente"[51]',
#  '"Axel F"[52]',
#  '"Perfect"[53]',
#  '"Waka Waka (This Time for Africa)"[54]',
#  '"Hello"[55]']

# %% [markdown]
# Scrap the Videos names

# %%
Artist_Name=[]
for i in Artist[0:30]:
    Artist_Name.append(i.text)
Artist_Name
# Out:
# ["Pinkfong Kids' Songs & Stories",
#  'Luis Fonsi',
#  'LooLoo Kids',
#  'Ed Sheeran',
#  'Wiz Khalifa',
#  'Cocomelon – Nursery Rhymes',
#  'Miroshka TV',
#  'Get Movies',
#  'Mark Ronson',
#  'Psy',
#  'ChuChu TV',
#  'El Chombo',
#  'Maroon 5',
#  'Justin Bieber',
#  'Katy Perry',
#  'OneRepublic',
#  'Ed Sheeran',
#  'Cocomelon – Nursery Rhymes',
#  'Katy Perry',
#  'Alan Walker',
#  'Maroon 5',
#  'Taylor Swift',
#  'Major Lazer',
#  'Enrique Iglesias',
#  'Passenger',
#  'J Balvin',
#  'Crazy Frog',
#  'Ed Sheeran',
#  'Shakira',
#  'Adele']

# %% [markdown]
# Scrap the Artist names

# %%
Video_Views=[]
for i in Views[0:30]:
    Video_Views.append(i.text)
Video_Views
# Out:
# ['9.20',
#  '7.50',
#  '5.65',
#  '5.43',
#  '5.23',
#  '4.47',
#  '4.45',
#  '4.45',
#  '4.27',
#  '4.16',
#  '4.10',
#  '3.54',
#  '3.54',
#  '3.46',
#  '3.41',
#  '3.37',
#  '3.31',
#  '3.23',
#  '3.13',
#  '3.12',
#  '3.10',
#  '3.09',
#  '3.08',
#  '3.08',
#  '3.06',
#  '2.96',
#  '2.95',
#  '2.93',
#  '2.92',
#  '2.87']

# %% [markdown]
# Scrap the Videos Views names

# %%
Upload_date=[]
for i in Date[0:30]:
    Upload_date.append(i.text)
Upload_date
# Out:
# ['June 17, 2016',
#  'January 12, 2017',
#  'October 8, 2016',
#  'January 30, 2017',
#  'April 6, 2015',
#  'May 2, 2018',
#  'February 27, 2018',
#  'January 31, 2012',
#  'November 19, 2014',
#  'July 15, 2012',
#  'March 6, 2014',
#  'April 5, 2018',
#  'January 14, 2015',
#  'October 22, 2015',
#  'September 5, 2013',
#  'May 31, 2013',
#  'October 7, 2014',
#  'May 24, 2018',
#  'February 20, 2014',
#  'December 3, 2015',
#  'May 31, 2018',
#  'August 18, 2014',
#  'March 22, 2015',
#  'April 11, 2014',
#  'July 25, 2012',
#  'June 29, 2017',
#  'June 16, 2009',
#  'November 9, 2017',
#  'June 4, 2010',
#  'October 22, 2015']

# %% [markdown]
# Scrap the Upload Date names

# %%
Video_Rank=[]
for i in Rank[0:30]:
    Video_Rank.append(i.text)
Video_Rank
# Out:
# ['[B]',
#  '[C]',
#  '[D]',
#  '[E]',
#  '[F]',
#  '[G]',
#  '[H]',
#  '[I]',
#  '[J]',
#  '[K]',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '']

# %% [markdown]
# Scrap the Videos Rank

# %%
print(len(video_Name),len(Artist_Name),len(Video_Views),len(Upload_date),len(Video_Rank))
# Out:
# 30 30 30 30 30

# %% [markdown]
# Length of the dataset

# %%
time.sleep(4)
# creating the dataframe from the scraped data and taking only first 10 jobs
df=pd.DataFrame({"Name":video_Name,"Artist_Name":Artist_Name,"Views":Video_Views,"Date":Upload_date,"Rank":Video_Rank})
df
# Out:
#                                                Name  \
# 0                            "Baby Shark Dance"[22]
# 1                                   "Despacito"[24]
# 2                        "Johny Johny Yes Papa"[25]
# 3                                "Shape of You"[26]
# 4                               "See You Again"[27]
# 5                                   "Bath Song"[30]
# 6   "Learning Colors – Colorful Eggs on a Farm"[31]
# 7    "Masha and the Bear – Recipe for Disaster"[32]
# 8                                 "Uptown Funk"[33]
# 9                               "Gangnam Style"[34]
# 10                "Phonics Song with Two Words"[36]
# 11                             "Dame Tu Cosita"[37]
# 12                                      "Sugar"[38]
# 13                                      "Sorry"[39]
# 14                                       "Roar"[40]
# 15                             "Counting Stars"[41]
# 16                          "Thinking Out Loud"[42]
# ...

# %% [markdown]
# Make a Dataframe of all the data

# %% [markdown]
# 2. Scrape the details team India’s international fixtures from bcci.tv.
# Url = https://www.bcci.tv/.
# You need to find following details:
# A) Match title (I.e. 1st ODI)
# B) Series
# C) Place
# D) Date
# E) Time
# Note: - From bcci.tv home page you have reach to the international fixture page through code.

# %%
#driver = webdriver.Chrome(r"C:\Users\Ankita\Downloads\chromedriver_win32\chromedriver.exe")
#time.sleep(2)

#url = "https://www.bcci.tv/international/fixtures"
#driver.get(url)
#time.sleep(2)

# %%
driver = webdriver.Chrome(r"C:\Users\Ankita\Downloads\chromedriver_win32\chromedriver.exe")
time.sleep(2)
url ="https://www.bcci.tv"
driver.get(url)

# %% [markdown]
# call chrome driver link and bcci tv link

# %%
button = driver.find_element_by_xpath("//div[@class='navigation__drop-down drop-down drop-down--reveal-on-hover']")               # locating search button
button.click()

# %% [markdown]
# Scrap and click on International button drop down link

# %%
button = driver.find_element_by_xpath("//a[@class='navigation__link navigation__link--in-drop-down']")               # locating search button
button.click()

# %% [markdown]
# Here click on International button drop down link seleck Fixtures option

# %%
Match_title=[]
Series=[]
Place=[]
Date_Time=[]
Time=[]

# %% [markdown]
# Dataframes of all the variables

# %%
Name=driver.find_elements_by_xpath("//div[@class='fixture__format-strip']//span[1]")
for i in Name[0:7]:
    if i.text is None :
        Match_title.append("--") 
    else:
        Match_title.append(i.text)
        
Date_Time_t=driver.find_elements_by_xpath("//span[@class='fixture__datetime tablet-only']")
for i in Date_Time_t[0:7]:
    if i.text is None :
        Date_Time.append("--") 
    else:
        Date_Time.append(i.text)
        
Place_t=driver.find_elements_by_xpath("//p[@class='fixture__additional-info']")
for i in Place_t[0:7]:
    if i.text is None :
        Place.append("--") 
    else:
        Place.append(i.text)
        
Series_t=driver.find_elements_by_xpath("//p[@class='fixture__additional-info']//strong[1]")
for i in Series_t[0:7]:
    if i.text is None :
        Series.append("--") 
    else:
        Series.append(i.text)

# %% [markdown]
# Here scrap the information like Match title, Date, Time, Place and Series

# %%
print(len(Match_title),len(Date_Time),len(Place),len(Series))
# Out:
# 14 14 14 14

# %%
df=pd.DataFrame({"Match_title":Match_title,"Date_Time":Date_Time,"Place":Place,"Series":Series})
df
# Out:
#    Match_title                                          Date_Time  \
# 0         TEST
# 1         TEST
# 2         T20I
# 3         T20I
# 4         T20I
# 5         T20I
# 6         T20I
# 7         TEST  Thursday 2nd September 15:30 IST (13:00 Your T...
# 8         TEST  Friday 10th September 15:30 IST (13:00 Your Ti...
# 9         T20I   Sunday 24th October 19:30 IST (17:00 Your Time )
# 10        T20I   Sunday 31st October 19:30 IST (17:00 Your Time )
# 11        T20I  Wednesday 3rd November 19:30 IST (17:00 Your T...
# 12        T20I   Friday 5th November 19:30 IST (17:00 Your Time )
# 13        T20I   Monday 8th November 19:30 IST (17:00 Your Time )
#
#                                                 Place    Series
# 0                          4th Test\nThe Oval, London  4th Test
# 1                  5th Test\nOld Trafford, Manchester  5th Test
# 2   Match 16\nDubai International Cricket Stadium,...  Match 16
# 3   Match 28\nDubai International Cricket Stadium,...  Match 28
# ...

# %% [markdown]
# Scrap all the data into dataframe

# %% [markdown]
# 3. Scrape the details of selenium exception from guru99.com.
# Url = https://www.guru99.com/
# You need to find following details:
# A) Name
# B) Description

# %%
#driver = webdriver.Chrome(r"C:\Users\Ankita\Downloads\chromedriver_win32\chromedriver.exe")
#time.sleep(2)

#url = "https://www.guru99.com/exception-handling-selenium.html"
#driver.get(url)
#time.sleep(2)

# %%
driver = webdriver.Chrome(r"C:\Users\Ankita\Downloads\chromedriver_win32\chromedriver.exe")
time.sleep(2)

url = "https://www.guru99.com"
driver.get(url)
time.sleep(2)

# %% [markdown]
# call chrome driver link and guru99 link

# %%
search = driver.find_element_by_xpath("/html/body/div[1]/div/div/div/main/div/article/div/div[1]/div[1]/div[2]/div/div[1]/div/div/div/form/table/tbody/tr/td[1]/div/table/tbody/tr/td[1]/input")                       

search.send_keys("selenium exception handling")

# %% [markdown]
# Search selenium exception handling on search bar

# %%
button = driver.find_element_by_xpath("//button[@class='gsc-search-button gsc-search-button-v2']")               # locating search button
button.click()

# %% [markdown]
#     Click on search button

# %%
button = driver.find_element_by_xpath("//a[@class='gs-title']")               # locating search button
button.click()

# %% [markdown]
# Click on selenium exception handling title

# %%
Exception_Name=[]
Exception_Description=[]

# %% [markdown]
# Make data frame for data

# %%
#Name=driver.find_elements_by_xpath("//a[@class='mw-redirect']")
Name=driver.find_elements_by_xpath("//table[@class='table table-striped']//td[1]")
for i in Name:
    if i.text is None :
        Exception_Name.append("--") 
    else:
        Exception_Name.append(i.text)
        
time.sleep(4)
#scraping the job-location
Desc=driver.find_elements_by_xpath("//table[@class='table table-striped']//td[2]")
for i in Desc:
    if i.text is None :
        Exception_Description.append("--") 
    else:
        Exception_Description.append(i.text)

# %% [markdown]
# Scrape and name and descriptin data link

# %%
Exception_Name=[]
for i in Name:
    Exception_Name.append(i.text)
Exception_Name
# Out:
# ['ElementNotVisibleException',
#  'ElementNotSelectableException',
#  'NoSuchElementException',
#  'NoSuchFrameException',
#  'NoAlertPresentException',
#  'NoSuchWindowException',
#  'StaleElementReferenceException',
#  'SessionNotFoundException',
#  'TimeoutException',
#  'WebDriverException',
#  'ConnectionClosedException',
#  'ElementClickInterceptedException',
#  'ElementNotInteractableException',
#  'ErrorInResponseException',
#  'ErrorHandler.UnknownServerException',
#  'ImeActivationFailedException',
#  'ImeNotAvailableException',
#  'InsecureCertificateException',
#  'InvalidArgumentException',
#  'InvalidCookieDomainException',
#  'InvalidCoordinatesException',
#  'InvalidElementStateExceptio',
#  'InvalidSessionIdException',
#  'InvalidSwitchToTargetException',
#  'JavascriptException',
#  'JsonException',
#  'NoSuchAttributeException',
#  'MoveTargetOutOfBoundsException',
#  'NoSuchContextException',
#  'NoSuchCookieException',
#  'NotFoundException',
# ...

# %% [markdown]
# Scrape the Names

# %%
Exception_Description=[]
for i in Desc:
    Exception_Description.append(i.text)
Exception_Description
# Out:
# ['This type of Selenium exception occurs when an existing element in DOM has a feature set as hidden.',
#  'This Selenium exception occurs when an element is presented in the DOM, but you can be able to select. Therefore, it is not possible to interact.',
#  'This Exception occurs if an element could not be found.',
#  'This Exception occurs if the frame target to be switched to does not exist.',
#  'This Exception occurs when you switch to no presented alert.',
#  'This Exception occurs if the window target to be switch does not exist.',
#  'This Selenium exception occurs happens when the web element is detached from the current DOM.',
#  'The WebDriver is acting after you quit the browser.',
#  'Thrown when there is not enough time for a command to be completed. For Example, the element searched wasn’t found in the specified time.',
#  'This Exception takes place when the WebDriver is acting right after you close the browser.',
# ...

# %% [markdown]
# Scrape description

# %%
print(len(Exception_Name),len(Exception_Description))
# Out:
# 41 41

# %%
time.sleep(4)
# creating the dataframe from the scraped data and taking only first 10 jobs
df=pd.DataFrame({"Name":Exception_Name,"Description":Exception_Description})
df
# Out:
#                                    Name  \
# 0            ElementNotVisibleException
# 1         ElementNotSelectableException
# 2                NoSuchElementException
# 3                  NoSuchFrameException
# 4               NoAlertPresentException
# 5                 NoSuchWindowException
# 6        StaleElementReferenceException
# 7              SessionNotFoundException
# 8                      TimeoutException
# 9                    WebDriverException
# 10            ConnectionClosedException
# 11     ElementClickInterceptedException
# 12      ElementNotInteractableException
# 13             ErrorInResponseException
# 14  ErrorHandler.UnknownServerException
# 15         ImeActivationFailedException
# 16             ImeNotAvailableException
# 17         InsecureCertificateException
# 18             InvalidArgumentException
# 19         InvalidCookieDomainException
# 20          InvalidCoordinatesException
# 21          InvalidElementStateExceptio
# ...

# %% [markdown]
# Scrape data into dataframe

# %% [markdown]
# 4. Scrape the details of State-wise GDP of India from statisticstime.com.
# Url = http://statisticstimes.com/
# You have to find following details:
# A) Rank
# B) State
# C) GSDP at current price (19-20)
# D) GSDP at current price (18-19)
# E) Share(18-19)
# F) GDP($ billion)

# %%
driver = webdriver.Chrome(r"C:\Users\Ankita\Downloads\chromedriver_win32\chromedriver.exe")
time.sleep(2)

url = "http://statisticstimes.com/"
driver.get(url)
time.sleep(2)

# %% [markdown]
# call chrome driver link and statisticstimes link

# %%
search_btn = driver.find_element_by_xpath("//div[@class='navbar']//div[2]")
search_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="aa5d496662ab288ed4dce36f32919223", element="51fc8b8d-744e-4128-9be7-38d582be652b")>

# %%
search_btn.click()

# %% [markdown]
# Click on economy button

# %%
search_btn = driver.find_element_by_xpath("//div[@class='dropdown-content']//a[3]")
search_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="aa5d496662ab288ed4dce36f32919223", element="10d1d9c9-a956-459e-a0b7-2bd4c94176d0")>

# %%
search_btn.click()

# %% [markdown]
# And select India option

# %%
search_btn = driver.find_element_by_xpath("/html/body/div[2]/div[2]/div[2]/ul/li[1]/a")
search_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="aa5d496662ab288ed4dce36f32919223", element="209a3f0c-f219-4bba-b928-fe3003ee1c15")>

# %%
search_btn.click()

# %% [markdown]
# And selectState-wise GDP of India option

# %%
Rank_GDP=[]
State_GDP=[]
GSDP19_20_price=[]
GSDP18_19_price=[]
Share18_19=[]
GDP_billion=[]

# %% [markdown]
# Dataframe od all the data which want to scrape

# %%
Rank=driver.find_elements_by_xpath("//tr[@class='odd']//td[1]")
for i in Rank:
    if i.text is None :
        Rank_GDP.append("--") 
    else:
        Rank_GDP.append(i.text)
        
time.sleep(4)
#scraping the job-location
State=driver.find_elements_by_xpath("//tr[@class='odd']//td[2]")
for i in State:
    if i.text is None :
        State_GDP.append("--") 
    else:
        State_GDP.append(i.text)
        
GSD19=driver.find_elements_by_xpath("//tr[@class='odd']//td[3]")
for i in GSD19:
    if i.text is None :
        GSDP19_20_price.append("--") 
    else:
        GSDP19_20_price.append(i.text)
        
time.sleep(4)
#scraping the job-location
GSD18=driver.find_elements_by_xpath("//tr[@class='odd']//td[4]")
for i in GSD18:
    if i.text is None :
        GSDP18_19_price.append("--") 
    else:
        GSDP18_19_price.append(i.text)
        
time.sleep(4)
#scraping the job-location
Share18=driver.find_elements_by_xpath("//tr[@class='odd']//td[5]")
for i in Share18:
    if i.text is None :
        Share18_19.append("--") 
    else:
        Share18_19.append(i.text)
        
time.sleep(4)
#scraping the job-location
Billion=driver.find_elements_by_xpath("//tr[@class='odd']//td[6]")
for i in Billion:
    if i.text is None :
        GDP_billion.append("--") 
    else:
        GDP_billion.append(i.text)

# %% [markdown]
# Scrape all the information link

# %%
print(len(Rank_GDP),len(State_GDP),len(GSDP19_20_price),len(GSDP18_19_price),len(Share18_19),len(GDP_billion))
# Out:
# 34 34 34 34 34 34

# %%
time.sleep(4)
# creating the dataframe from the scraped data and taking only first 10 jobs
df=pd.DataFrame({"Rank_GDP":Rank_GDP,"State_GDP":State_GDP,"GSDP19_20_price":GSDP19_20_price,"GSDP18_19_price":GSDP18_19_price,"Share18_19":Share18_19,"GDP_billion":GDP_billion})
df
# Out:
#    Rank_GDP                  State_GDP GSDP19_20_price GSDP18_19_price  \
# 0         1                Maharashtra               -       2,632,792
# 1         3              Uttar Pradesh       1,687,818       1,584,764
# 2         5                  Karnataka       1,631,977       1,493,127
# 3         7                  Rajasthan       1,020,989         942,586
# 4         9                  Telangana         969,604         861,031
# 5        11                     Kerala               -         781,653
# 6        13                    Haryana         831,610         734,163
# 7        15                     Punjab         574,760         526,376
# 8        17                      Assam               -         315,881
# 9        19                  Jharkhand         328,598         297,204
# 10       21            Jammu & Kashmir               -         155,956
# 11       23                        Goa          80,449          73,170
# ...

# %% [markdown]
# Make dataframe of all the data

# %% [markdown]
# 5. Scrape the details of trending repositories on Github.com.
# Url = https://github.com/
# You have to find the following details:
# A) Repository title
# B) Repository description
# C) Contributors count
# D) Language used

# %%
driver = webdriver.Chrome(r"C:\Users\Ankita\Downloads\chromedriver_win32\chromedriver.exe")
time.sleep(2)

url = "https://github.com/"
driver.get(url)
time.sleep(2)

# %% [markdown]
# call chrome driver link and github link

# %%
search_btn = driver.find_element_by_xpath("//input[@class='form-control input-sm header-search-input jump-to-field js-jump-to-field js-site-search-focus']")
search_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="fecde249e7e2dac7a002bb3867f66351", element="514b6c88-6fc5-4f18-8101-8b066fdad03a")>

# %%
search_btn.send_keys("trending repositories")

# %% [markdown]
# Click on search and search for trending repositories

# %%
search_btn = driver.find_element_by_xpath("//div[@class='jump-to-suggestion-name js-jump-to-suggestion-name flex-auto overflow-hidden text-left no-wrap css-truncate css-truncate-target']")
search_btn.click
# Out:
# <bound method WebElement.click of <selenium.webdriver.remote.webelement.WebElement (session="fecde249e7e2dac7a002bb3867f66351", element="00fed9f9-35d2-4610-a227-78d624ae3671")>>

# %% [markdown]
# Click on search button

# %%
Repository_title=[]
Repository_description=[]
Contributors_count=[]
Language_used=[]

# %% [markdown]
# Make dataframe of all the data which want to scrape

# %%
Repository=driver.find_elements_by_xpath("//div[@class='f4 text-normal']//a[1]")
for i in Repository[0:9]:
    if i.text is None :
        Repository_title.append("--") 
    else:
        Repository_title.append(i.text)
        
time.sleep(4)
#scraping the job-location
Desc=driver.find_elements_by_xpath("//p[@class='mb-1']//em[1]")
for i in Desc[0:9]:
    if i.text is None :
        Repository_description.append("--") 
    else:
        Repository_description.append(i.text)
        
count=driver.find_elements_by_xpath("//div[@class='mr-3']//a[1]")
for i in count[0:9]:
    if i.text is None :
        Contributors_count.append("--") 
    else:
        Contributors_count.append(i.text)
        
time.sleep(4)
#scraping the job-location
Language=driver.find_elements_by_xpath("//div[@class='mr-3']//span[2]")
for i in Language[0:9]:
    if i.text is None :
        Language_used.append("--") 
    else:
        Language_used.append(i.text)

# %% [markdown]
# Scraoe all the data link

# %%
print(len(Repository_title),len(Repository_description),len(Contributors_count),len(Language_used))
# Out:
# 9 9 9 9

# %%
time.sleep(4)
# creating the dataframe from the scraped data and taking only first 10 jobs
df=pd.DataFrame({"Repository_title":Repository_title,"Repository_description":Repository_description,"Contributors_count":Contributors_count,"Language_used":Language_used})
df
# Out:
#                     Repository_title Repository_description  \
# 0     vitalets/github-trending-repos               trending
# 1     mbadry1/Trending-Deep-Learning               trending
# 2  Semigradsky/trending-repositories           repositories
# 3                laowch/GithubTrends               Trending
# 4                    ophobe/trending               trending
# 5             ecrmnn/trending-github               trending
# 6                 zhuowenli/githuber               Trending
# 7                  QasimWani/LeetHub               trending
# 8        andygrunwald/TrendingGithub               trending
#
#   Contributors_count Language_used
# 0               2.2k          HTML
# 1                556        Python
# 2                 77    JavaScript
# 3                640          Java
# 4                 58    TypeScript
# 5                 56    JavaScript
# 6                437    JavaScript
# 7                680            Go
# 8                 99            Go

# %% [markdown]
# Make dataframe of all the data

# %% [markdown]
# 6. Scrape the details of top 100 songs on billboard.com.
# Url = https://www.billboard.com/
# You have to find the following details:
# A) Song name
# B) Artist name
# C) Last week rank
# D) Peak rank
# E) Weeks on board

# %%
driver = webdriver.Chrome(r"C:\Users\Ankita\Downloads\chromedriver_win32\chromedriver.exe")
time.sleep(2)

url = "https://www.billboard.com/"
driver.get(url)
time.sleep(2)

# %% [markdown]
# call chrome driver link and billboard link

# %%
search_btn = driver.find_element_by_xpath("//li[@class='header__main-link__wrapper']//a[1]")
search_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="521314706c50a4dff6a1ccf28dc0c9b7", element="f5482c9e-f793-4e8d-b55a-08813d105a60")>

# %%
search_btn.click
# Out:
# <bound method WebElement.click of <selenium.webdriver.remote.webelement.WebElement (session="521314706c50a4dff6a1ccf28dc0c9b7", element="f5482c9e-f793-4e8d-b55a-08813d105a60")>>

# %% [markdown]
# Click and select top 100 song button

# %%
search_btn = driver.find_element_by_xpath("/html/body/main/div[2]/div/div[1]/a/div[2]/div[1]")
search_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="521314706c50a4dff6a1ccf28dc0c9b7", element="1d08fd36-ad2a-4ca5-b553-1af0fba37eb5")>

# %%
search_btn.click
# Out:
# <bound method WebElement.click of <selenium.webdriver.remote.webelement.WebElement (session="521314706c50a4dff6a1ccf28dc0c9b7", element="1d08fd36-ad2a-4ca5-b553-1af0fba37eb5")>>

# %% [markdown]
# Click search button

# %%
Song_name=[]
Artist_name=[]
Last_week_rank=[]
Peak_rank=[]
Weeks_on_board=[]

# %% [markdown]
# Scrape all the dataframe create

# %%
Song=driver.find_elements_by_xpath("//span[@class='chart-element__information__song text--truncate color--primary']")
for i in Song:
    if i.text is None :
        Song_name.append("--") 
    else:
        Song_name.append(i.text)
        
time.sleep(4)
#scraping the job-location
Artist=driver.find_elements_by_xpath("//span[@class='chart-element__information__artist text--truncate color--secondary']")
for i in Artist:
    if i.text is None :
        Artist_name.append("--") 
    else:
        Artist_name.append(i.text)
        
Rank=driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--last']")
for i in Rank:
    if i.text is None :
        Last_week_rank.append("--") 
    else:
        Last_week_rank.append(i.text)
        
time.sleep(4)
#scraping the job-location
Peak=driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--peak']")
for i in Peak:
    if i.text is None :
        Peak_rank.append("--") 
    else:
        Peak_rank.append(i.text)
        
time.sleep(4)
#scraping the job-location
Weaks=driver.find_elements_by_xpath("//div[@class='chart-element__meta text--center color--secondary text--week']")
for i in Weaks:
    if i.text is None :
        Weeks_on_board.append("--") 
    else:
        Weeks_on_board.append(i.text)

# %% [markdown]
# Scrape all the links of the data

# %%
print(len(Song_name),len(Artist_name),len(Last_week_rank),len(Peak_rank),len(Weeks_on_board))
# Out:
# 100 100 100 100 100

# %%
time.sleep(4)
# creating the dataframe from the scraped data and taking only first 10 jobs
df=pd.DataFrame({"Song_name":Song_name,"Artist_name":Artist_name,"Last_week_rank":Last_week_rank,"Peak_rank":Peak_rank,"Weeks_on_board":Weeks_on_board})
df
# Out:
#               Song_name                                        Artist_name  \
# 0                  Stay                      The Kid LAROI & Justin Bieber
# 1            Bad Habits                                         Ed Sheeran
# 2              Good 4 U                                     Olivia Rodrigo
# 3          Kiss Me More                             Doja Cat Featuring SZA
# 4         Industry Baby                            Lil Nas X & Jack Harlow
# ..                  ...                                                ...
# 95            Tick Tock                                         Young Thug
# 96  Permission To Dance                                                BTS
# 97                   AM                  Nio Garcia X J Balvin X Bad Bunny
# 98           Time Heals                                           Rod Wave
# 99   Thinking 'Bout You  Dustin Lynch Featuring Lauren Alaina Or MacKen...
#
#    Last_week_rank Peak_rank Weeks_on_board
# ...

# %% [markdown]
# Make dataframe of data

# %% [markdown]
# 7. Scrape the details of Data science recruiters from naukri.com.
# Url = https://www.naukri.com/
# You have to find the following details:
# A) Name
# B) Designation
# C) Company
# D) Skills they hire for
# E) Location
# Note: - From naukri.com homepage click on the recruiters option and the on the search pane type Data science and
# click on search. All this should be done through code

# %%
driver = webdriver.Chrome(r"C:\Users\Ankita\Downloads\chromedriver_win32\chromedriver.exe")
time.sleep(2)

url = "https://www.naukri.com/jobs-in-india"
driver.get(url)
time.sleep(2)

# %% [markdown]
# call chrome driver link and www.naukri.com link

# %%
#driver = webdriver.Chrome(r"C:\Users\Ankita\Downloads\chromedriver_win32\chromedriver.exe")
#time.sleep(2)

#url = "https://www.naukri.com/data-science-recruiters"
#driver.get(url)
#time.sleep(2)

# %%
search_btn = driver.find_element_by_xpath("//div[@class='mTxt']")
search_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="06917b87da9be7202f227105b5ca071f", element="f78fd5ba-77b7-447a-ad01-de8d392046d2")>

# %%
search_btn.click()

# %% [markdown]
# Click on recruitment option

# %%
search_job = driver.find_element_by_id('qsb-keyword-sugg')
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="0ca07e0d030339abb3df4c728d5f30d9", element="366da652-bdd4-44a1-9a78-cf19d2e9301d")>

# %%
search_job.send_keys("Data Science")

# %% [markdown]
# Click on search option and search for Data Science

# %%
search_btn = driver.find_element_by_xpath("//button[@class='btn-primary']")
search_btn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="0ca07e0d030339abb3df4c728d5f30d9", element="0032a74f-510d-4a35-aa93-24a59ee508a3")>

# %%
search_btn.click()

# %% [markdown]
# Click on search button

# %%
Name=[]
Designation=[]
Company=[]
Skills_they_hire=[]
Location=[]

# %% [markdown]
# Scrape all the dataframe create

# %%
Name_j=driver.find_elements_by_xpath("//a[@class='ellipsis']")
for i in Name_j[0:48]:
    if i.text is None :
        Name.append("--") 
    else:
        Name.append(i.text)
        
Company_j=driver.find_elements_by_xpath("//div[@class='vcard']//a[2]")
for i in Company_j[0:48]:
    if i.text is None :
        Company.append("--") 
    else:
        Company.append(i.text)
        
Skills_they_hire_j=driver.find_elements_by_xpath("//div[@class='hireSec highlightable']")
for i in Skills_they_hire_j[0:48]:
    if i.text is None :
        Skills_they_hire.append("--") 
    else:
        Skills_they_hire.append(i.text)
        
Location_j=driver.find_elements_by_xpath("//small[@class='ellipsis']")
for i in Location_j[0:48]:
    if i.text is None :
        Location.append("--") 
    else:
        Location.append(i.text)

# %% [markdown]
# C

# %%
print(len(Name),len(Company),len(Skills_they_hire),len(Location))
# Out:
# 48 48 48 48

# %%
df=pd.DataFrame({"Name":Name,"Company":Company,"Skills_they_hire":Skills_they_hire,"Location":Location})
df
# Out:
#                                              Name  \
# 0                                    Aakash Harit
# 1                            Data Science Network
# 2                            shravan Kumar Gaddam
# 3                   Shore Infotech India Pvt. Ltd
# 4                        MARSIAN Technologies LLP
# 5                        MARSIAN Technologies LLP
# 6                                    Anik Agrawal
# 7           Enerlytics Software Solutions Pvt Ltd
# 8                                    subhas patel
# 9                                 LibraryXProject
# 10   Abhishek - Only Analytics Hiring - India and
# 11     Apidel Technologies Division of Transpower
# 12  Institute for Financial Management and Resear
# 13                                           IFMR
# 14                                    Balu Ramesh
# 15                    Techvantage Systems Pvt Ltd
# 16                                  Asif Lucknowi
# 17                     Weupskill- Live Wire India
# ...

# %% [markdown]
# Make datframe of all the data

# %% [markdown]
# 8. Scrape the details of Highest selling novels.
# Url = https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-greycompare/
# You have to find the following details:
# A) Book name
# B) Author name
# C) Volumes sold
# D) Publisher
# E) Genre

# %%
driver = webdriver.Chrome(r"C:\Users\Ankita\Downloads\chromedriver_win32\chromedriver.exe")
time.sleep(2)

url = "https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare"
driver.get(url)
time.sleep(2)

# %% [markdown]
# call chrome driver link and https://www.theguardian.com/news/datablog/2012/aug/09/best-selling-books-all-time-fifty-shades-grey-compare link

# %%
Book_name=[]
Author_name=[]
Volumes_sold=[]
Publisher=[]
Genre=[]

# %% [markdown]
# Scrape all the dataframe create

# %%
Book=driver.find_elements_by_xpath("//table[@class='in-article sortable']//td[1]")
for i in Book[0:100]:
    if i.text is None :
        Book_name.append("--") 
    else:
        Book_name.append(i.text)
       

 #scraping the job-location
Author=driver.find_elements_by_xpath("//table[@class='in-article sortable']//td[2]")
for i in Author:
    if i.text is None :
        Author_name.append("--") 
    else:
        Author_name.append(i.text)
        
Volumes=driver.find_elements_by_xpath("//table[@class='in-article sortable']//td[3]")
for i in Volumes:
    if i.text is None :
        Volumes_sold.append("--") 
    else:
        Volumes_sold.append(i.text)
        
time.sleep(4)
#scraping the job-location
Publ=driver.find_elements_by_xpath("//table[@class='in-article sortable']//td[4]")
for i in Publ:
    if i.text is None :
        Publisher.append("--") 
    else:
        Publisher.append(i.text)
        
time.sleep(4)
#scraping the job-location
Genre_n=driver.find_elements_by_xpath("//table[@class='in-article sortable']//td[5]")
for i in Genre_n:
    if i.text is None :
        Genre.append("--") 
    else:
        Genre.append(i.text)

# %% [markdown]
# Scrape all the dataframe create

# %%
print(len(Book_name),len(Author_name),len(Volumes_sold),len(Publisher),len(Genre))
# Out:
# 100 100 100 100 100

# %%
#time.sleep(4)
# creating the dataframe from the scraped data and taking only first 10 jobs
df=pd.DataFrame({"Book_name":Book_name,"Author_name":Author_name,"Volumes_sold":Volumes_sold,"Publisher":Publisher,"Genre":Genre})
df
# Out:
#                     Book_name  \
# 0   SOURCE: NIELSEN BOOK SCAN
# 1                           1
# 2                           2
# 3                           3
# 4                           4
# ..                        ...
# 95                         95
# 96                         96
# 97                         97
# 98                         98
# 99                         99
#
#                                           Author_name      Volumes_sold  \
# 0                                   Da Vinci Code,The        Brown, Dan
# 1                Harry Potter and the Deathly Hallows     Rowling, J.K.
# 2            Harry Potter and the Philosopher's Stone     Rowling, J.K.
# 3           Harry Potter and the Order of the Phoenix     Rowling, J.K.
# 4                                Fifty Shades of Grey      James, E. L.
# ..                                                ...               ...
# 95                                          Ghost,The    Harris, Robert
# ...

# %% [markdown]
# Make dataframe of all the data

# %% [markdown]
# 9. Scrape the details most watched tv series of all time from imdb.com.
#  Url = https://www.imdb.com/list/ls095964455/
# You have to find the following details:
# A) Name
# B) Year span
# C) Genre
# D) Run time
# E) Ratings
# F) Votes

# %%
driver = webdriver.Chrome(r"C:\Users\Ankita\Downloads\chromedriver_win32\chromedriver.exe")
#time.sleep(2)

url = "https://www.imdb.com/list/ls095964455/"
driver.get(url)
#time.sleep(2)

# %% [markdown]
# call chrome driver link and https://www.imdb.com/list/ls095964455/ link

# %%
Name=[]
Year_span=[]
Genre=[]
Run_time=[]
Ratings=[]
Votes=[]

# %% [markdown]
# Scrape all the dataframe create

# %%
Series_name=driver.find_elements_by_xpath("//h3[@class='lister-item-header']//a[1]")
for i in Series_name:
    if i.text is None :
        Name.append("--") 
    else:
        Name.append(i.text)
       
 #scraping the job-location
year=driver.find_elements_by_xpath("//span[@class='lister-item-year text-muted unbold']")
for i in year:
    if i.text is None :
        Year_span.append("--") 
    else:
        Year_span.append(i.text)
        
Genre_name=driver.find_elements_by_xpath("//p[@class='text-muted text-small']//span[5]")
for i in Genre_name:
    if i.text is None :
        Genre.append("--") 
    else:
        Genre.append(i.text)
        
#time.sleep(4)
#scraping the job-location
time=driver.find_elements_by_xpath("//div[@class='lister-item-content']//span[3]")
for i in time:
    if i.text is None :
        Run_time.append("--") 
    else:
        Run_time.append(i.text)
        
#time.sleep(4)
#scraping the job-location
Genre_name=driver.find_elements_by_xpath("//span[@class='genre']")
for i in Genre_name:
    if i.text is None :
        Genre.append("--") 
    else:
        Genre.append(i.text)
        
#time.sleep(4)
#scraping the job-location
Ratings_name=driver.find_elements_by_xpath("//div[@class='ipl-rating-widget']//span[2]")
for i in Ratings_name[0:100]:
    if i.text is None :
        Ratings.append("--") 
    else:
        Ratings.append(i.text)
        
#time.sleep(4)
#scraping the job-location
Votes_n=driver.find_elements_by_xpath("//p[@class='text-muted text-small']//span[2]")
for i in Votes_n[0:100]:
    if i.text is None :
        Votes.append("--") 
    else:
        Votes.append(i.text)

# %% [markdown]
# Scrape all the data and links

# %%
print(len(Name),len(Year_span),len(Genre_name),len(Run_time),len(Ratings),len(Votes))
# Out:
# 100 100 100 100 100 100

# %%
#time.sleep(4)
# creating the dataframe from the scraped data and taking only first 10 jobs
df=pd.DataFrame({"Name":Name,"Year_span":Year_span,"Genre_name":Genre_name,"Run_time":Run_time,"Ratings":Ratings,"Votes":Votes})
df
# Out:
#                               Name    Year_span  \
# 0                  Game of Thrones  (2011–2019)
# 1                  Stranger Things     (2016– )
# 2                 The Walking Dead  (2010–2022)
# 3                   13 Reasons Why  (2017–2020)
# 4                          The 100  (2014–2020)
# ..                             ...          ...
# 95                           Reign  (2013–2017)
# 96  A Series of Unfortunate Events  (2017–2019)
# 97                  Criminal Minds  (2005–2020)
# 98           Scream: The TV Series  (2015–2019)
# 99      The Haunting of Hill House       (2018)
#
#                                            Genre_name Run_time Ratings  \
# 0   <selenium.webdriver.remote.webelement.WebEleme...   57 min     9.2
# 1   <selenium.webdriver.remote.webelement.WebEleme...   51 min
# 2   <selenium.webdriver.remote.webelement.WebEleme...   44 min    Rate
# 3   <selenium.webdriver.remote.webelement.WebEleme...   60 min
# ...

# %% [markdown]
# Make dataframe of all the data

# %% [markdown]
# 10. Details of Datasets from UCI machine learning repositories.
#  Url = https://archive.ics.uci.edu/
#  You have to find the following details:
# A) Dataset name
# B) Data type
# C) Task
# D) Attribute type
# E) No of instances
# F) No of attribute
# G) Year
# Note: - from the home page you have to go to the Show All Dataset page through code

# %%
driver = webdriver.Chrome(r"C:\Users\Ankita\Downloads\chromedriver_win32\chromedriver.exe")
#time.sleep(2)

url = "https://archive.ics.uci.edu/ml/index.php"
driver.get(url)
#time.sleep(2)

# %%
Name=[]
Data_type=[]
Task=[]
Attribute_type=[]
No_of_instances=[]
No_of_attribute=[]
Year=[]

# %%
Dataset_name=driver.find_elements_by_xpath("//span[@class='normal']//a[1]")
for i in Dataset_name:
    if i.text is None :
        Name.append("--") 
    else:
        Name.append(i.text)

# %%
df=pd.DataFrame({"Name":Name})
df
# Out:
#                                                  Name
# 0
# 1                                  view all data sets
# 2                                          About page
# 3                                                Note
# 4                                       Mobile Robots
# 5
# 6                        Synchronous Machine Data Set
# 7                           Wikipedia Math Essentials
# 8                           Wikipedia Math Essentials
# 9                          Hungarian Chickenpox Cases
# 10                Myocardial infarction complications
# 11                                Gait Classification
# 12                                        Codon usage
# 13                   in-vehicle coupon recommendation
# 14                                   Dry Bean Dataset
# 15  Intelligent Media Accelerometer and Gyroscope ...
# 16           AI4I 2020 Predictive Maintenance Dataset
# 17                         Wisesight Sentiment Corpus
# ...
