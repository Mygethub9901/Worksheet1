# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Loading Library

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# Use to display all columns in dataset

# %%
df=pd.read_csv(r'C:\Users\Ankita\Desktop\Data file.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  label       msisdn    aon  daily_decr30  daily_decr90  \
# 0           1      0  21408I70789  272.0   3055.050000   3065.150000
# 1           2      1  76462I70374  712.0  12122.000000  12124.750000
# 2           3      1  17943I70372  535.0   1398.000000   1398.000000
# 3           4      1  55773I70781  241.0     21.228000     21.228000
# 4           5      1  03813I82730  947.0    150.619333    150.619333
#
#    rental30  rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  \
# 0    220.13    260.13                2.0                0.0              1539
# 1   3691.26   3691.26               20.0                0.0              5787
# 2    900.13    900.13                3.0                0.0              1539
# 3    159.42    159.42               41.0                0.0               947
# 4   1098.90   1098.90                4.0                0.0              2309
#
#    cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# ...

# %% [markdown]
# Loading the data First 5 rows of dataset

# %%
df.tail()
# Out:
#         Unnamed: 0  label       msisdn     aon  daily_decr30  daily_decr90  \
# 209588      209589      1  22758I85348   404.0    151.872333    151.872333
# 209589      209590      1  95583I84455  1075.0     36.936000     36.936000
# 209590      209591      1  28556I85350  1013.0  11843.111667  11904.350000
# 209591      209592      1  59712I82733  1732.0  12488.228333  12574.370000
# 209592      209593      1  65061I85339  1581.0   4489.362000   4534.820000
#
#         rental30  rental90  last_rech_date_ma  last_rech_date_da  \
# 209588   1089.19   1089.19                1.0                0.0
# 209589   1728.36   1728.36                4.0                0.0
# 209590   5861.83   8893.20                3.0                0.0
# 209591    411.83    984.58                2.0               38.0
# 209592    483.92    631.20               13.0                0.0
#
#         last_rech_amt_ma  cnt_ma_rech30  fr_ma_rech30  sumamnt_ma_rech30  \
# ...

# %% [markdown]
# Loading the data last 5 rows of dataset

# %%
df = df.drop(columns=['Unnamed: 0'])

# %%
df = df.drop(columns=['pcircle'])

# %%
df["pdate"] = pd.to_datetime(df["pdate"])

# %% [markdown]
# Drop Unnamed: 0 column in dataset because it is not much imporatant

# %%
df.shape
# Out:
# (209593, 35)

# %% [markdown]
# there was 209593 rows 36 columns in dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 209593 entries, 0 to 209592
# Data columns (total 35 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   label                 209593 non-null  int64
#  1   msisdn                209593 non-null  object
#  2   aon                   209593 non-null  float64
#  3   daily_decr30          209593 non-null  float64
#  4   daily_decr90          209593 non-null  float64
#  5   rental30              209593 non-null  float64
#  6   rental90              209593 non-null  float64
#  7   last_rech_date_ma     209593 non-null  float64
#  8   last_rech_date_da     209593 non-null  float64
#  9   last_rech_amt_ma      209593 non-null  int64
#  10  cnt_ma_rech30         209593 non-null  int64
#  11  fr_ma_rech30          209593 non-null  float64
#  12  sumamnt_ma_rech30     209593 non-null  float64
#  13  medianamnt_ma_rech30  209593 non-null  float64
# ...

# %% [markdown]
# Describe dataset information

# %%
df.isnull().sum()
# Out:
# label                   0
# msisdn                  0
# aon                     0
# daily_decr30            0
# daily_decr90            0
# rental30                0
# rental90                0
# last_rech_date_ma       0
# last_rech_date_da       0
# last_rech_amt_ma        0
# cnt_ma_rech30           0
# fr_ma_rech30            0
# sumamnt_ma_rech30       0
# medianamnt_ma_rech30    0
# medianmarechprebal30    0
# cnt_ma_rech90           0
# fr_ma_rech90            0
# sumamnt_ma_rech90       0
# medianamnt_ma_rech90    0
# medianmarechprebal90    0
# cnt_da_rech30           0
# fr_da_rech30            0
# cnt_da_rech90           0
# fr_da_rech90            0
# cnt_loans30             0
# amnt_loans30            0
# maxamnt_loans30         0
# medianamnt_loans30      0
# cnt_loans90             0
# amnt_loans90            0
# maxamnt_loans90         0
# medianamnt_loans90      0
# payback30               0
# payback90               0
# pdate                   0
# dtype: int64

# %% [markdown]
# There was no null values is present in dataset

# %%
df.loc[:,df.isnull().any()].isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
df.columns
# Out:
# Index(['label', 'msisdn', 'aon', 'daily_decr30', 'daily_decr90', 'rental30',
#        'rental90', 'last_rech_date_ma', 'last_rech_date_da',
#        'last_rech_amt_ma', 'cnt_ma_rech30', 'fr_ma_rech30',
#        'sumamnt_ma_rech30', 'medianamnt_ma_rech30', 'medianmarechprebal30',
#        'cnt_ma_rech90', 'fr_ma_rech90', 'sumamnt_ma_rech90',
#        'medianamnt_ma_rech90', 'medianmarechprebal90', 'cnt_da_rech30',
#        'fr_da_rech30', 'cnt_da_rech90', 'fr_da_rech90', 'cnt_loans30',
#        'amnt_loans30', 'maxamnt_loans30', 'medianamnt_loans30', 'cnt_loans90',
#        'amnt_loans90', 'maxamnt_loans90', 'medianamnt_loans90', 'payback30',
#        'payback90', 'pdate'],
#       dtype='object')

# %% [markdown]
# Describe dataset columns

# %%
df.describe()
# Out:
#                label            aon   daily_decr30   daily_decr90  \
# count  209593.000000  209593.000000  209593.000000  209593.000000
# mean        0.875177    8112.343445    5381.402289    6082.515068
# std         0.330519   75696.082531    9220.623400   10918.812767
# min         0.000000     -48.000000     -93.012667     -93.012667
# 25%         1.000000     246.000000      42.440000      42.692000
# 50%         1.000000     527.000000    1469.175667    1500.000000
# 75%         1.000000     982.000000    7244.000000    7802.790000
# max         1.000000  999860.755168  265926.000000  320630.000000
#
#             rental30       rental90  last_rech_date_ma  last_rech_date_da  \
# count  209593.000000  209593.000000      209593.000000      209593.000000
# mean     2692.581910    3483.406534        3755.847800        3712.202921
# std      4308.586781    5770.461279       53905.892230       53374.833430
# min    -23737.140000  -24720.580000         -29.000000         -29.000000
# ...

# %% [markdown]
# Describe dataset

# %%
df.dtypes
# Out:
# label                            int64
# msisdn                          object
# aon                            float64
# daily_decr30                   float64
# daily_decr90                   float64
# rental30                       float64
# rental90                       float64
# last_rech_date_ma              float64
# last_rech_date_da              float64
# last_rech_amt_ma                 int64
# cnt_ma_rech30                    int64
# fr_ma_rech30                   float64
# sumamnt_ma_rech30              float64
# medianamnt_ma_rech30           float64
# medianmarechprebal30           float64
# cnt_ma_rech90                    int64
# fr_ma_rech90                     int64
# sumamnt_ma_rech90                int64
# medianamnt_ma_rech90           float64
# medianmarechprebal90           float64
# cnt_da_rech30                  float64
# fr_da_rech30                   float64
# cnt_da_rech90                    int64
# fr_da_rech90                     int64
# ...

# %% [markdown]
# Describe datatypes of dataset

# %%
df.duplicated().sum()
# Out:
# 1

# %% [markdown]
# check duplicates values in dataset there was 1 duplicates value was present

# %%
df.drop_duplicates()
# Out:
#         label       msisdn     aon  daily_decr30  daily_decr90  rental30  \
# 0           0  21408I70789   272.0   3055.050000   3065.150000    220.13
# 1           1  76462I70374   712.0  12122.000000  12124.750000   3691.26
# 2           1  17943I70372   535.0   1398.000000   1398.000000    900.13
# 3           1  55773I70781   241.0     21.228000     21.228000    159.42
# 4           1  03813I82730   947.0    150.619333    150.619333   1098.90
# ...       ...          ...     ...           ...           ...       ...
# 209588      1  22758I85348   404.0    151.872333    151.872333   1089.19
# 209589      1  95583I84455  1075.0     36.936000     36.936000   1728.36
# 209590      1  28556I85350  1013.0  11843.111667  11904.350000   5861.83
# 209591      1  59712I82733  1732.0  12488.228333  12574.370000    411.83
# 209592      1  65061I85339  1581.0   4489.362000   4534.820000    483.92
#
#         rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  \
# ...

# %%
df.drop_duplicates(["last_rech_date_ma"])
# Out:
#         label       msisdn     aon  daily_decr30  daily_decr90  rental30  \
# 0           0  21408I70789   272.0   3055.050000   3065.150000    220.13
# 1           1  76462I70374   712.0  12122.000000  12124.750000   3691.26
# 2           1  17943I70372   535.0   1398.000000   1398.000000    900.13
# 3           1  55773I70781   241.0     21.228000     21.228000    159.42
# 4           1  03813I82730   947.0    150.619333    150.619333   1098.90
# ...       ...          ...     ...           ...           ...       ...
# 209057      1  89443I82736  1096.0     76.076000     76.076000    238.55
# 209374      1  39810I82730  1319.0     56.602333     56.602333    921.69
# 209466      1  59525I88698   190.0   2601.750000   2622.100000   -334.62
# 209501      1  54642I70787   460.0     55.520000     55.520000    877.40
# 209533      0  41672I95204   168.0     15.400000     15.400000    922.20
#
#         rental90  last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  \
# ...

# %% [markdown]
# Drop that duplicate vale

# %%
df.loc[:, df.dtypes == object]
# Out:
#              msisdn
# 0       21408I70789
# 1       76462I70374
# 2       17943I70372
# 3       55773I70781
# 4       03813I82730
# ...             ...
# 209588  22758I85348
# 209589  95583I84455
# 209590  28556I85350
# 209591  59712I82733
# 209592  65061I85339
#
# [209593 rows x 1 columns]

# %% [markdown]
# Describe object datatype columns in dataset

# %%
categorical_columns = []
for x in df.dtypes.index:
    if df.dtypes[x] == 'object':
        categorical_columns.append(x)

# %%
categorical_columns
# Out:
# ['msisdn']

# %% [markdown]
# display columns name in which object datatype are present in Dataset

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
for i in list(df.columns):
    if df[i].dtype=='object':
        df[i]=le.fit_transform(df[i])

# %%
df.head()
# Out:
#    label  msisdn    aon  daily_decr30  daily_decr90  rental30  rental90  \
# 0      0   40191  272.0   3055.050000   3065.150000    220.13    260.13
# 1      1  142291  712.0  12122.000000  12124.750000   3691.26   3691.26
# 2      1   33594  535.0   1398.000000   1398.000000    900.13    900.13
# 3      1  104157  241.0     21.228000     21.228000    159.42    159.42
# 4      1    6910  947.0    150.619333    150.619333   1098.90   1098.90
#
#    last_rech_date_ma  last_rech_date_da  last_rech_amt_ma  cnt_ma_rech30  \
# 0                2.0                0.0              1539              2
# 1               20.0                0.0              5787              1
# 2                3.0                0.0              1539              1
# 3               41.0                0.0               947              0
# 4                4.0                0.0              2309              7
#
#    fr_ma_rech30  sumamnt_ma_rech30  medianamnt_ma_rech30  \
# ...

# %% [markdown]
# Use Lable Encoder to convert categorical values converted into numeric in dataset

# %%
categorical_columns = []
for x in df.dtypes.index:
    if df.dtypes[x] == 'object':
        categorical_columns.append(x)

# %%
categorical_columns
# Out:
# []

# %% [markdown]
# now there was no object datatype was present in dataset

# %%
df = df.drop(columns=['pdate'])

# %% [markdown]
# Drop the pdate column in dataset because it is not more important

# %% [markdown]
# Univarient Analysis of Dataset:

# %%
sns.countplot(df['label']);
print(df["label"].value_counts())
# Out:
# 1    183431
# 0     26162
# Name: label, dtype: int64

# %% [markdown]
# Distribution of the target column

# %%
sns.countplot(df['cnt_ma_rech30']);

# %% [markdown]
# Distribution of the cnt_ma_rech30 column

# %%
sns.countplot(df['cnt_loans30']);

# %% [markdown]
# Distribution of the cnt_loans30 column

# %%
sns.countplot(df['maxamnt_loans90']);

# %% [markdown]
# Distribution of the maxamnt_loans90 column

# %%
sns.countplot(df['amnt_loans90']);

# %% [markdown]
# Distribution of the amnt_loans90 column

# %% [markdown]
# Checking Distribution of Dataset:

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
sns.distplot(df['label'],kde=True)
plt.subplot(1,2,2)
sns.distplot(df['msisdn'],kde=True)
# Out:
# <AxesSubplot:xlabel='msisdn', ylabel='Density'>

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
sns.distplot(df['aon'],kde=True)
plt.subplot(1,2,2)
sns.distplot(df['daily_decr30'],kde=True)
# Out:
# <AxesSubplot:xlabel='daily_decr30', ylabel='Density'>

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
sns.distplot(df['daily_decr90'],kde=True)
plt.subplot(1,2,2)
sns.distplot(df['rental30'],kde=True)
# Out:
# <AxesSubplot:xlabel='rental30', ylabel='Density'>

# %% [markdown]
# Here some columns are not normally distributed and some columns are not normally distributed

# %% [markdown]
# Bi varient Analysis:

# %%
plt.figure(figsize=[10,6])
plt.title('comparision')
sns.scatterplot(df["msisdn"],df["aon"],hue=df["label"])
plt.show()

# %% [markdown]
# Distribution between 2 columns and hue target column

# %%
plt.figure(figsize=[10,6])
plt.title('comparision')
sns.scatterplot(df["daily_decr30"],df["daily_decr90"],hue=df["label"])
plt.show()

# %% [markdown]
# Distribution between 2 columns and hue target column

# %%
plt.figure(figsize=[10,6])
plt.title('comparision')
sns.scatterplot(df["rental30"],df["rental90"],hue=df["label"])
plt.show()

# %% [markdown]
# Distribution between 2 columns and hue target column

# %%
plt.figure(figsize=[10,6])
plt.title('Comparision')
#sns.scatterplot(df["TV"],df["radio"],alpha=0.5,c=(0,0,0),edgecolors='r')
sns.scatterplot(df["cnt_ma_rech30"],df["cnt_ma_rech90"],df["fr_ma_rech90"],hue=df["label"])
plt.show()

# %% [markdown]
# Distribution between 3 columns and hue target column

# %%
plt.figure(figsize=[10,6])
plt.title('Comparision')
sns.scatterplot(df["cnt_loans30"],df["amnt_loans30"],hue=df["label"])
plt.show()

# %% [markdown]
# Distribution between 2 columns and hue target column

# %%
plt.figure(figsize=[10,6])
plt.title('Comparision')
sns.scatterplot(df["maxamnt_loans30"],df["medianamnt_loans30"],hue=df["label"])
plt.show()

# %% [markdown]
# Distribution between 2 columns and hue target column

# %%
plt.figure(figsize=[10,6])
plt.title('Comparision')
sns.scatterplot(df["cnt_loans90"],df["amnt_loans90"],df["maxamnt_loans90"],hue=df["label"])
plt.show()

# %% [markdown]
# Distribution between 3 columns and hue target column

# %% [markdown]
# Checking Outliers:

# %%
df.iloc[:,0:5].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
df.iloc[:,6:10].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
df.iloc[:,11:15].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
df.iloc[:,16:20].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
df.iloc[:,21:25].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
df.iloc[:,26:30].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %%
df.iloc[:,31:35].boxplot(figsize=[20,8])
plt.subplots_adjust(bottom=0.25)
plt.show()

# %% [markdown]
# Here Outlier is present in many columns in Dataset

# %% [markdown]
# Multivarient Analysis:

# %% [markdown]
# HistPlot:

# %%
df.hist( bins = 10, figsize = (25,25))
plt.show()

# %% [markdown]
# Bar plot of all columns

# %% [markdown]
# HeatMap of Dataset:

# %%
cor=df.corr()

# %%
cor
# Out:
#                          label    msisdn       aon  daily_decr30  \
# label                 1.000000  0.001976 -0.003785      0.168298
# msisdn                0.001976  1.000000  0.000566      0.000717
# aon                  -0.003785  0.000566  1.000000      0.001104
# daily_decr30          0.168298  0.000717  0.001104      1.000000
# daily_decr90          0.166150  0.000950  0.000374      0.977704
# rental30              0.058085 -0.001404 -0.000960      0.442066
# rental90              0.075521 -0.000691 -0.000790      0.458977
# last_rech_date_ma     0.003728 -0.000928  0.001692      0.000487
# last_rech_date_da     0.001711  0.001400 -0.001693     -0.001636
# last_rech_amt_ma      0.131804 -0.002368  0.004256      0.275837
# cnt_ma_rech30         0.237331  0.000617 -0.003148      0.451385
# fr_ma_rech30          0.001330 -0.001804 -0.001163     -0.000577
# sumamnt_ma_rech30     0.202828  0.001094  0.000707      0.636536
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Checking correlation of all the independent column with target column in dataset

# %%
plt.figure(figsize=(15,10))
df.corr()['label'].sort_values(ascending=False).drop(['label']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %% [markdown]
# Correlation with another way

# %% [markdown]
# Use zscore method for data loss:

# %%
X=df.drop("label",axis=1)
y=df["label"]

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
new_df=df[(z<3).all(axis=1)]

# %%
new_df.shape
# Out:
# (161465, 34)

# %%
df.shape
# Out:
# (209593, 34)

# %%
Data_loss=((209593-161465)/209593)*100

# %%
Data_loss
# Out:
# 22.962598941758554

# %% [markdown]
# Here 100 persent dataloss using zscore

# %% [markdown]
# Use IQR technique for data loss:

# %%
Q1=df.quantile(0.25)
Q3=df.quantile(0.75)
IQR=Q3-Q1
df_new=df[~((df<(Q1-1.5*IQR))|(df>(Q3+1.5*IQR))).any(axis=1)]

# %%
df_new.shape
# Out:
# (56628, 34)

# %% [markdown]
# Using IQR more dataloss

# %% [markdown]
# Checking skewness:

# %%
df.skew()
# Out:
# label                   -2.270254
# msisdn                   0.000719
# aon                     10.392949
# daily_decr30             3.946230
# daily_decr90             4.252565
# rental30                 4.521929
# rental90                 4.437681
# last_rech_date_ma       14.790974
# last_rech_date_da       14.814857
# last_rech_amt_ma         3.781149
# cnt_ma_rech30            3.283842
# fr_ma_rech30            14.772833
# sumamnt_ma_rech30        6.386787
# medianamnt_ma_rech30     3.512324
# medianmarechprebal30    14.779875
# cnt_ma_rech90            3.425254
# fr_ma_rech90             2.285423
# sumamnt_ma_rech90        4.897950
# medianamnt_ma_rech90     3.752706
# medianmarechprebal90    44.880503
# cnt_da_rech30           17.818364
# fr_da_rech30            14.776430
# cnt_da_rech90           27.267278
# fr_da_rech90            28.988083
# cnt_loans30              2.713421
# amnt_loans30             2.975719
# maxamnt_loans30         17.658052
# ...

# %%
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer()
dfpt=pt.fit_transform(df)
df=pd.DataFrame(dfpt,columns=df.columns)

# %%
df['label']=np.log(df['label'])

# %%
df['aon']=np.log(df['aon'])

# %%
df['daily_decr30']=np.log(df['daily_decr30'])

# %%
df['daily_decr90']=np.log(df['daily_decr90'])

# %%
df['fr_da_rech30']=np.log(df['fr_da_rech30'])

# %% [markdown]
# Use power transform and log transform to remove skewness

# %%
df.skew()
# Out:
# label                   0.000000
# msisdn                 -0.054149
# aon                    -0.596237
# daily_decr30           -0.008672
# daily_decr90           -0.010461
# rental30               -0.015017
# rental90               -0.018603
# last_rech_date_ma      -0.071476
# last_rech_date_da       0.010041
# last_rech_amt_ma        0.016294
# cnt_ma_rech30           0.027247
# fr_ma_rech30            0.078270
# sumamnt_ma_rech30       0.089057
# medianamnt_ma_rech30    0.095486
# medianmarechprebal30    0.241723
# cnt_ma_rech90           0.019385
# fr_ma_rech90            0.053129
# sumamnt_ma_rech90       0.054121
# medianamnt_ma_rech90    0.037206
# medianmarechprebal90    0.008513
# cnt_da_rech30           0.268902
# fr_da_rech30                 NaN
# cnt_da_rech90           0.000000
# fr_da_rech90            0.000000
# cnt_loans30            -0.064990
# amnt_loans30           -0.131656
# maxamnt_loans30         0.000000
# medianamnt_loans30     -0.151994
# ...

# %%
df.skew()
# Out:
# label                   0.000000
# msisdn                 -0.054149
# aon                    -0.596237
# daily_decr30           -0.008672
# daily_decr90           -0.010461
# rental30               -0.015017
# rental90               -0.018603
# last_rech_date_ma      -0.071476
# last_rech_date_da       0.010041
# last_rech_amt_ma        0.016294
# cnt_ma_rech30           0.027247
# fr_ma_rech30            0.078270
# sumamnt_ma_rech30       0.089057
# medianamnt_ma_rech30    0.095486
# medianmarechprebal30    0.241723
# cnt_ma_rech90           0.019385
# fr_ma_rech90            0.053129
# sumamnt_ma_rech90       0.054121
# medianamnt_ma_rech90    0.037206
# medianmarechprebal90    0.008513
# cnt_da_rech30           0.268902
# fr_da_rech30           -5.190070
# cnt_da_rech90           0.000000
# fr_da_rech90            0.000000
# cnt_loans30            -0.064990
# amnt_loans30           -0.131656
# maxamnt_loans30         0.000000
# medianamnt_loans30     -0.151994
# ...

# %% [markdown]
# After Removing Skewness

# %% [markdown]
# Oversampling:

# %% [markdown]
# SMOTE for balance data:

# %%
X=df.copy()
X.drop('label',axis=1,inplace=True)
y=df['label']

# %%
from imblearn.over_sampling import SMOTE
over=SMOTE()

# %%
X,y=over.fit_resample(X,y)

# %%
y.value_counts()
# Out:
# 1    183431
# 0    183431
# Name: label, dtype: int64

# %%
sns.countplot(y)
# Out:
# <AxesSubplot:xlabel='label', ylabel='count'>

# %%
Using SMOTE

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()

# %%
Xd=scaler.fit_transform(X)
X=pd.DataFrame(Xd,columns=X.columns)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
import warnings
warnings.filterwarnings('ignore')

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %% [markdown]
# Importing Library

# %%
from sklearn.tree import DecisionTreeClassifier
maxAccu=0
maxRS=0
for i in range(1,200):
    X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.30, random_state=52)
    mod = DecisionTreeClassifier()
    mod.fit(X_train, y_train)
    pred = mod.predict(X_test)
    acc=accuracy_score(y_test, pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
        print("Best accuracy is",maxAccu,"on Random_state ",maxRS)
# Out:
# Best accuracy is 0.8637838353637202 on Random_state  1
# Best accuracy is 0.8638315468049238 on Random_state  5
# Best accuracy is 0.8646108336779159 on Random_state  8
# Best accuracy is 0.8649448137663411 on Random_state  92

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=.30,random_state=52)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import classification_report

# %%
DTC = DecisionTreeClassifier()
DTC.fit(X_train, y_train)
pred = DTC.predict(X_test)
acc=classification_report(y_test, pred)
print(acc)
print(confusion_matrix(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.45      0.48      0.47      7814
#            1       0.93      0.92      0.92     55064
#
#     accuracy                           0.86     62878
#    macro avg       0.69      0.70      0.69     62878
# weighted avg       0.87      0.86      0.86     62878
#
# [[ 3738  4076]
#  [ 4519 50545]]

# %% [markdown]
# Use DecisionTreeClassifier and check accuracy score

# %%
RFC = RandomForestClassifier()
RFC.fit(X_train, y_train)
pred = RFC.predict(X_test)
acc=classification_report(y_test, pred)
print(acc)
print(confusion_matrix(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.44      0.56      7814
#            1       0.92      0.98      0.95     55064
#
#     accuracy                           0.91     62878
#    macro avg       0.85      0.71      0.75     62878
# weighted avg       0.91      0.91      0.90     62878
#
# [[ 3411  4403]
#  [ 1010 54054]]

# %% [markdown]
# Use RandomForestClassifier and check accuracy score

# %%
SV = SVC()
SV.fit(X_train, y_train)
pred = SV.predict(X_test)
acc=classification_report(y_test, pred)
print(acc)
print(confusion_matrix(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00      7814
#            1       0.88      1.00      0.93     55064
#
#     accuracy                           0.88     62878
#    macro avg       0.44      0.50      0.47     62878
# weighted avg       0.77      0.88      0.82     62878
#
# [[    0  7814]
#  [    0 55064]]

# %% [markdown]
# Use SVC and check accuracy score

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import  GaussianNB
from sklearn.neighbors import KNeighborsClassifier

# %%
Ad = AdaBoostClassifier()
Ad.fit(X_train, y_train)
pred = Ad.predict(X_test)
acc=classification_report(y_test, pred)
print(acc)
print(confusion_matrix(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.62      0.18      0.28      7814
#            1       0.89      0.98      0.94     55064
#
#     accuracy                           0.88     62878
#    macro avg       0.76      0.58      0.61     62878
# weighted avg       0.86      0.88      0.86     62878
#
# [[ 1404  6410]
#  [  874 54190]]

# %% [markdown]
# Use AdaBoostClassifier and check accuracy score

# %%
GB = GradientBoostingClassifier()
GB.fit(X_train, y_train)
pred = GB.predict(X_test)
acc=classification_report(y_test, pred)
print(acc)
print(confusion_matrix(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.36      0.49      7814
#            1       0.92      0.99      0.95     55064
#
#     accuracy                           0.91     62878
#    macro avg       0.85      0.67      0.72     62878
# weighted avg       0.90      0.91      0.89     62878
#
# [[ 2794  5020]
#  [  768 54296]]

# %% [markdown]
# Use GradientBoostingClassifier and check accuracy score

# %%
lr = LogisticRegression()
lr.fit(X_train, y_train)
pred = lr.predict(X_test)
acc=classification_report(y_test, pred)
print(acc)
print(confusion_matrix(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.55      0.00      0.01      7814
#            1       0.88      1.00      0.93     55064
#
#     accuracy                           0.88     62878
#    macro avg       0.71      0.50      0.47     62878
# weighted avg       0.84      0.88      0.82     62878
#
# [[   29  7785]
#  [   24 55040]]

# %% [markdown]
# Use LogisticRegression and check accuracy score

# %%
Ga =  GaussianNB()
Ga.fit(X_train, y_train)
pred = Ga.predict(X_test)
acc=classification_report(y_test, pred)
print(acc)
print(confusion_matrix(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.21      0.87      0.34      7814
#            1       0.97      0.54      0.69     55064
#
#     accuracy                           0.58     62878
#    macro avg       0.59      0.70      0.52     62878
# weighted avg       0.87      0.58      0.65     62878
#
# [[ 6768  1046]
#  [25306 29758]]

# %% [markdown]
# Use GaussianNB and check accuracy score

# %%
KN = KNeighborsClassifier()
KN.fit(X_train, y_train)
pred = KN.predict(X_test)
acc=classification_report(y_test, pred)
print(acc)
print(confusion_matrix(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.44      0.27      0.33      7814
#            1       0.90      0.95      0.93     55064
#
#     accuracy                           0.87     62878
#    macro avg       0.67      0.61      0.63     62878
# weighted avg       0.84      0.87      0.85     62878
#
# [[ 2073  5741]
#  [ 2606 52458]]

# %% [markdown]
# Use KNeighborsClassifier and check accuracy score

# %%
from sklearn.model_selection import cross_val_score

# %%
print(cross_val_score(DTC,X,y,cv=5).mean())
# Out:
# 0.8655680339327791

# %%
print(cross_val_score(RFC,X,y,cv=5).mean())
# Out:
# 0.9136850999420462

# %%
print(cross_val_score(SV,X,y,cv=5).mean())

# %%
print(cross_val_score(Ad,X,y,cv=5).mean())
# Out:
# 0.885020021863203

# %%
print(cross_val_score(GB,X,y,cv=5).mean())
# Out:
# 0.906246870853826

# %%
print(cross_val_score(lr,X,y,cv=5).mean())
# Out:
# 0.8752439253644517

# %%
print(cross_val_score(Ga,X,y,cv=5).mean())
# Out:
# 0.5803008877090476

# %%
print(cross_val_score(KN,X,y,cv=5).mean())
# Out:
# 0.8674669486479427

# %% [markdown]
# Check cross validation of all the algorithms

# %% [markdown]
# Here RandomForestClassifier are best and high accuracy score so apply Hyper parameter tunning on it

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# Import GridsearcgCv

# %%
import numpy as np

# %%
parameters = {'n_estimators': [200,700],
                'max_features': ['auto','sqrt'],
                 'max_depth': [4,5],
              'criterion' : ['gini','entropy']}

# %% [markdown]
# Import parameters

# %%
GCV=GridSearchCV(RandomForestClassifier(),parameters,cv=5)

# %% [markdown]
# Import GridSearchCV library

# %%
GCV.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=RandomForestClassifier(bootstrap=True, ccp_alpha=0.0,
#                                               class_weight=None,
#                                               criterion='gini', max_depth=None,
#                                               max_features='auto',
#                                               max_leaf_nodes=None,
#                                               max_samples=None,
#                                               min_impurity_decrease=0.0,
#                                               min_impurity_split=None,
#                                               min_samples_leaf=1,
#                                               min_samples_split=2,
#                                               min_weight_fraction_leaf=0.0,
#                                               n_estimators=100, n_jobs=None,
#                                               oob_score=False,
# ...

# %%
GCV.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 5,
#  'max_features': 'auto',
#  'n_estimators': 200}

# %% [markdown]
# Best parameter list of RandomForestClassifier

# %%
Final_mod2 = RandomForestClassifier(criterion= 'gini',max_depth=5,max_features='auto',n_estimators=700)
Final_mod2.fit(X_train,y_train)
pred = Final_mod2.predict(X_test)
acc=accuracy_score(y_test,pred)
print(acc*100)
# Out:
# 90.10464709437323

# %% [markdown]
# Finally print best score

# %% [markdown]
# AUC and ROC Curve:

# %%
from sklearn.metrics import plot_roc_curve

# %%
plot_roc_curve(Final_mod2,X_test,y_test)

# %%
import joblib
joblib.dump(Final_mod2,"micro_credit.pk1")
# Out:
# ['micro_credit.pk1']

# %% [markdown]
# Importing the model

# %%
model=joblib.load("micro_credit.pk1")

# %%
print(model.predict(X_test))
# Out:
# [1 1 1 ... 1 1 1]

# %% [markdown]
# Finally creating best model
