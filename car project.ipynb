# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Loading Library

# %%
df=pd.read_csv(r'D:\users\Ankita\Desktop\cardata.csv')

# %% [markdown]
# Use to display all columns in dataset

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %% [markdown]
# Loading the data First 5 rows of dataset

# %%
df.shape
# Out:
# (4999, 13)

# %% [markdown]
# there was 5000 rows 13 columns in dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4999 entries, 0 to 4998
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           4999 non-null   object
#  1   year           4999 non-null   int64
#  2   selling_price  4999 non-null   int64
#  3   km_driven      4999 non-null   int64
#  4   fuel           4999 non-null   object
#  5   seller_type    4999 non-null   object
#  6   transmission   4999 non-null   object
#  7   owner          4999 non-null   object
#  8   mileage        4859 non-null   object
#  9   engine         4859 non-null   object
#  10  max_power      4865 non-null   object
#  11  torque         4858 non-null   object
#  12  seats          4859 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 507.8+ KB

# %% [markdown]
# Describe dataset information

# %%
df.isnull().sum()
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          140
# engine           140
# max_power        134
# torque           141
# seats            140
# dtype: int64

# %% [markdown]
# There was no null values is present in dataset

# %%
df.loc[:,df.isnull().any()].isnull().sum()
# Out:
# mileage      140
# engine       140
# max_power    134
# torque       141
# seats        140
# dtype: int64

# %% [markdown]
# There are many columns null values are present

# %%
df.nunique()
# Out:
# name             1624
# year               28
# selling_price     536
# km_driven         665
# fuel                4
# seller_type         3
# transmission        2
# owner               5
# mileage           356
# engine            117
# max_power         294
# torque            385
# seats               8
# dtype: int64

# %% [markdown]
# Value count of all the columns in dataset

# %%
df.columns
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'torque',
#        'seats'],
#       dtype='object')

# %% [markdown]
# Describe dataset columns

# %%
df.describe()
# Out:
#               year  selling_price     km_driven        seats
# count  4999.000000   4.999000e+03  4.999000e+03  4859.000000
# mean   2013.846369   6.554750e+05  6.920242e+04     5.430130
# std       3.999750   8.406464e+05  6.062143e+04     0.968315
# min    1983.000000   3.000000e+04  1.000000e+03     4.000000
# 25%    2011.000000   2.595000e+05  3.500000e+04     5.000000
# 50%    2015.000000   4.500000e+05  6.000000e+04     5.000000
# 75%    2017.000000   6.800000e+05  9.510000e+04     5.000000
# max    2020.000000   1.000000e+07  2.360457e+06    14.000000

# %% [markdown]
# Describe dataset

# %%
df.dtypes
# Out:
# name              object
# year               int64
# selling_price      int64
# km_driven          int64
# fuel              object
# seller_type       object
# transmission      object
# owner             object
# mileage           object
# engine            object
# max_power         object
# torque            object
# seats            float64
# dtype: object

# %% [markdown]
# Describe all the datatypes in dataset

# %%
df.duplicated().sum()
# Out:
# 676

# %% [markdown]
# Count duplicates values of dataset

# %%
df[df.duplicated()]
# Out:
#                                           name  year  selling_price  \
# 291                   Hyundai Grand i10 Sportz  2017         450000
# 296                           Maruti Swift VXI  2012         330000
# 370   Jaguar XE 2016-2019 2.0L Diesel Prestige  2017        2625000
# 371                              Lexus ES 300h  2019        5150000
# 372             Jaguar XF 2.0 Diesel Portfolio  2017        3200000
# ...                                        ...   ...            ...
# 4970                       Mahindra Bolero SLX  2011         340000
# 4972                       Mahindra Bolero SLX  2007         245000
# 4984                   Mahindra XUV500 W10 2WD  2015        1000000
# 4985                    Chevrolet Spark 1.0 LS  2008          65000
# 4986               Maruti Ignis 1.2 Delta BSIV  2019         500000
#
#       km_driven    fuel seller_type transmission         owner     mileage  \
# ...

# %% [markdown]
# Display duplicates values in dataset

# %%
df = df.drop_duplicates(subset = ['name','year','selling_price', 'km_driven', 'seller_type','transmission','owner','engine','max_power','torque','seats','mileage'], keep = 'first')

# %% [markdown]
# Drop the duplicate values from dataset

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# After remove duplicates values from dataset now no duplicate values was present in dataset

# %%
categorical_columns = []
for x in df.dtypes.index:
    if df.dtypes[x] == 'object':
        categorical_columns.append(x)

# %%
categorical_columns
# Out:
# ['name',
#  'fuel',
#  'seller_type',
#  'transmission',
#  'owner',
#  'mileage',
#  'engine',
#  'max_power',
#  'torque']

# %% [markdown]
# Above are the list of duplicate values in dataset

# %%
df['name'].unique()
# Out:
# array(['Maruti Swift Dzire VDI', 'Skoda Rapid 1.5 TDI Ambition',
#        'Honda City 2017-2020 EXi', ..., 'Mahindra Logan Petrol 1.4 GLE',
#        'Maruti Ciaz VDi Option SHVS', 'Toyota Qualis FS B3'], dtype=object)

# %% [markdown]
# Unique values list in name column

# %%
df['fuel'].unique()
# Out:
# array(['Diesel', 'Petrol', 'LPG', 'CNG'], dtype=object)

# %% [markdown]
# Unique values list in fuel column

# %%
df['mileage'] = df['mileage'].apply(lambda x: float(str(x).split()[0]))
df['engine'] = df['engine'].apply(lambda x: float(str(x).split()[0]))
df['max_power'] = df['max_power'].str.strip("bhp").replace(" ", "")
df['max_power'] =pd.to_numeric(df['max_power'],errors='coerce')

# %% [markdown]
# In above columns categorical and numerical values combination was present so split that values and convert it into numeric

# %%
import datetime as dt
df['company'] = df['name'].apply(lambda x: x.split()[0])
df['age_of_car'] = dt.datetime.today().year - df['year']
df.drop(['year','name','torque'],inplace=True,axis=1)
df.head()
# Out:
#    selling_price  km_driven    fuel seller_type transmission         owner  \
# 0         450000     145500  Diesel  Individual       Manual   First Owner
# 1         370000     120000  Diesel  Individual       Manual  Second Owner
# 2         158000     140000  Petrol  Individual       Manual   Third Owner
# 3         225000     127000  Diesel  Individual       Manual   First Owner
# 4         130000     120000  Petrol  Individual       Manual   First Owner
#
#    mileage  engine  max_power  seats  company  age_of_car
# 0    23.40  1248.0      74.00    5.0   Maruti           7
# 1    21.14  1498.0     103.52    5.0    Skoda           7
# 2    17.70  1497.0      78.00    5.0    Honda          15
# 3    23.00  1396.0      90.00    5.0  Hyundai          11
# 4    16.10  1298.0      88.20    5.0   Maruti          14

# %% [markdown]
# After split the values describe dataset
# and drop some column becaise all unique values is present and not much impotant

# %%
df['owner'].unique()
# Out:
# array(['First Owner', 'Second Owner', 'Third Owner',
#        'Fourth & Above Owner', 'Test Drive Car'], dtype=object)

# %% [markdown]
# Unique values list in owner column

# %%
df['owner'].replace({'First Owner':1,'Second Owner':2,
                     'Third Owner':3,'Fourth & Above Owner':4,
                      'Test Drive Car':6},
                    inplace=True)

# %% [markdown]
# Replace categrical values into numeric in owner column

# %%
df['fuel'].unique()
# Out:
# array(['Diesel', 'Petrol', 'LPG', 'CNG'], dtype=object)

# %% [markdown]
# Unique values list in fuel column

# %%
df['seller_type'].unique()
# Out:
# array(['Individual', 'Dealer', 'Trustmark Dealer'], dtype=object)

# %% [markdown]
# Unique values list in seller_type column

# %%
df['transmission'].unique()
# Out:
# array(['Manual', 'Automatic'], dtype=object)

# %% [markdown]
# Unique values list in transmission column

# %%
df['company'].unique()
# Out:
# array(['Maruti', 'Skoda', 'Honda', 'Hyundai', 'Toyota', 'Ford', 'Renault',
#        'Mahindra', 'Tata', 'Chevrolet', 'Fiat', 'Datsun', 'Jeep',
#        'Mercedes-Benz', 'Mitsubishi', 'Audi', 'Volkswagen', 'BMW',
#        'Nissan', 'Lexus', 'Jaguar', 'Land', 'MG', 'Volvo', 'Daewoo',
#        'Kia', 'Force', 'Ambassador', 'Ashok', 'Isuzu', 'Opel'],
#       dtype=object)

# %% [markdown]
# Unique values list in company column

# %%
from sklearn.preprocessing import LabelEncoder
label = LabelEncoder()
df['fuel'] = label.fit_transform(df['fuel'])
df['seller_type'] = label.fit_transform(df['seller_type'])
df['transmission'] = label.fit_transform(df['transmission'])
df['company'] = label.fit_transform(df['company'])

# %% [markdown]
# Use Lable Encoder to convert categorical values converted into numeric in dataset

# %%
df.dtypes
# Out:
# selling_price      int64
# km_driven          int64
# fuel               int32
# seller_type        int32
# transmission       int32
# owner              int64
# mileage          float64
# engine           float64
# max_power        float64
# seats            float64
# company            int32
# age_of_car         int64
# dtype: object

# %% [markdown]
# After converting categorical column into numeric and display dataset

# %%
df.head()
# Out:
#    selling_price  km_driven  fuel  seller_type  transmission  owner  mileage  \
# 0         450000     145500     1            1             1      1    23.40
# 1         370000     120000     1            1             1      2    21.14
# 2         158000     140000     3            1             1      3    17.70
# 3         225000     127000     1            1             1      1    23.00
# 4         130000     120000     3            1             1      1    16.10
#
#    engine  max_power  seats  company  age_of_car
# 0  1248.0      74.00    5.0       20           7
# 1  1498.0     103.52    5.0       26           7
# 2  1497.0      78.00    5.0       10          15
# 3  1396.0      90.00    5.0       11          11
# 4  1298.0      88.20    5.0       20          14

# %% [markdown]
# After converting categorical columns into nuemric display dataset

# %%
plt.figure(figsize=[16,6])
sns.heatmap(df.isnull())
plt.title("Null values")
plt.show()

# %% [markdown]
# Heatmap shows the many null values was present in dataset

# %% [markdown]
# Univarient Analysis of Dataset:

# %%
sns.countplot(df['selling_price']);
print(df["selling_price"].value_counts())
# Out:
# 300000     134
# 350000     125
# 400000     109
# 550000     108
# 500000     107
#           ...
# 1864999      1
# 244000       1
# 151000       1
# 839000       1
# 699000       1
# Name: selling_price, Length: 536, dtype: int64

# %% [markdown]
# Distribution of the target column

# %%
sns.countplot(df['km_driven']);

# %% [markdown]
# Distribution of the km_driven column

# %%
sns.countplot(df['fuel']);

# %% [markdown]
# Distribution of the fuel column

# %%
sns.countplot(df['seller_type']);

# %% [markdown]
# Distribution of the seller_type column

# %%
sns.countplot(df['transmission']);

# %% [markdown]
# Distribution of the transmission column

# %%
sns.countplot(df['owner']);

# %% [markdown]
# Distribution of the owner column

# %%
sns.countplot(df['seats']);

# %% [markdown]
# Distribution of the seats column

# %% [markdown]
# Checking Distribution of Dataset:

# %%
sns.distplot(df["selling_price"])
# Out:
# <AxesSubplot:xlabel='selling_price', ylabel='Density'>

# %%
sns.distplot(df["km_driven"])
# Out:
# <AxesSubplot:xlabel='km_driven', ylabel='Density'>

# %%
sns.distplot(df["fuel"])
# Out:
# <AxesSubplot:xlabel='fuel', ylabel='Density'>

# %%
sns.distplot(df["seller_type"])
# Out:
# <AxesSubplot:xlabel='seller_type', ylabel='Density'>

# %%
sns.distplot(df["transmission"])
# Out:
# <AxesSubplot:xlabel='transmission', ylabel='Density'>

# %%
sns.distplot(df["owner"])
# Out:
# <AxesSubplot:xlabel='owner', ylabel='Density'>

# %%
sns.distplot(df["mileage"])
# Out:
# <AxesSubplot:xlabel='mileage', ylabel='Density'>

# %%
sns.distplot(df["engine"])
# Out:
# <AxesSubplot:xlabel='engine', ylabel='Density'>

# %%
sns.distplot(df["max_power"])
# Out:
# <AxesSubplot:xlabel='max_power', ylabel='Density'>

# %%
sns.distplot(df["seats"])
# Out:
# <AxesSubplot:xlabel='seats', ylabel='Density'>

# %% [markdown]
# Here some columns are not normally distributed and some columns are not normally distributed

# %% [markdown]
# Checking Outliers:

# %%
sns.boxplot(df["selling_price"])
# Out:
# <AxesSubplot:xlabel='selling_price'>

# %%
sns.boxplot(df["km_driven"])
# Out:
# <AxesSubplot:xlabel='km_driven'>

# %%
sns.boxplot(df["fuel"])
# Out:
# <AxesSubplot:xlabel='fuel'>

# %%
sns.boxplot(df["seller_type"])
# Out:
# <AxesSubplot:xlabel='seller_type'>

# %%
sns.boxplot(df["transmission"])
# Out:
# <AxesSubplot:xlabel='transmission'>

# %%
sns.boxplot(df["owner"])
# Out:
# <AxesSubplot:xlabel='owner'>

# %%
sns.boxplot(df["mileage"])
# Out:
# <AxesSubplot:xlabel='mileage'>

# %%
sns.boxplot(df["engine"])
# Out:
# <AxesSubplot:xlabel='engine'>

# %%
sns.boxplot(df["max_power"])
# Out:
# <AxesSubplot:xlabel='max_power'>

# %%
sns.boxplot(df["seats"])
# Out:
# <AxesSubplot:xlabel='seats'>

# %% [markdown]
# Here Outlier is present in all columns in Dataset only fuel column outlier is not present

# %% [markdown]
# Bi varient Analysis:

# %%
plt.figure(figsize=[10,6])
plt.title('comparision')
sns.scatterplot(df["km_driven"],df["fuel"],hue=df["selling_price"])
plt.show()

# %% [markdown]
# Distribution between 2 columns and hue target column

# %%
plt.figure(figsize=[10,6])
plt.title('comparision')
sns.scatterplot(df["seller_type"],df["transmission"],hue=df["selling_price"])
plt.show()

# %% [markdown]
# Distribution between 2 columns and hue target column

# %%
plt.figure(figsize=[10,6])
plt.title('comparision')
sns.scatterplot(df["owner"],df["mileage"],hue=df["selling_price"])
plt.show()

# %% [markdown]
# Distribution between 2 columns and hue target column

# %%
plt.figure(figsize=[10,6])
plt.title('comparision')
sns.scatterplot(df["engine"],df["max_power"],hue=df["selling_price"])
plt.show()

# %% [markdown]
# Distribution between 2 columns and hue target column

# %%
plt.figure(figsize=[10,6])
plt.title('comparision')
sns.scatterplot(df["engine"],df["max_power"],df["seats"],hue=df["selling_price"])
plt.show()

# %% [markdown]
# Distribution between 2 columns and hue target column

# %% [markdown]
# Multivarient Analysis:

# %% [markdown]
# HistPlot:

# %%
df.hist( bins = 10, figsize = (10,10))
plt.show()

# %% [markdown]
# Bar plot of all columns

# %%
df.plot(kind='density', subplots=True, layout=(6,11), sharex=False, legend=False, fontsize=1, figsize=(18,12))
plt.show()

# %%
sns.pairplot(df, hue='selling_price')

# %% [markdown]
# pair plot of all the columns

# %%
df['mileage'].fillna(df['mileage'].mode()[0], inplace=True)
df['engine'].fillna(df['engine'].mode()[0], inplace=True)
df["seats"]=df["seats"].fillna(df["seats"].mean())
df['max_power'].fillna(df['max_power'].mode()[0], inplace=True)

# %% [markdown]
# Here fill null values in columns

# %%
df.loc[:,df.isnull().any()].isnull().sum()
# Out:
# Series([], dtype: float64)

# %% [markdown]
# Now no null values are present in dataset

# %% [markdown]
# Correlation of dataset:

# %% [markdown]
# HeatMap of Dataset:

# %%
cor=df.corr()

# %%
cor
# Out:
#                selling_price  km_driven      fuel  seller_type  transmission  \
# selling_price       1.000000  -0.151983 -0.226371    -0.282231     -0.472047
# km_driven          -0.151983   1.000000 -0.249675     0.095565      0.119868
# fuel               -0.226371  -0.249675  1.000000     0.051974     -0.038233
# seller_type        -0.282231   0.095565  0.051974     1.000000      0.201774
# transmission       -0.472047   0.119868 -0.038233     0.201774      1.000000
# owner              -0.181179   0.237056 -0.015467     0.129202      0.073716
# mileage            -0.109037  -0.181669 -0.084795     0.001150      0.183350
# engine              0.442995   0.225605 -0.506102    -0.084901     -0.230198
# max_power           0.703615   0.031660 -0.287662    -0.201257     -0.454506
# seats               0.136472   0.206609 -0.353273     0.037032      0.019048
# company            -0.054581   0.099631 -0.160947     0.053322      0.072734
# ...

# %%
plt.figure(figsize=(15,10))
sns.heatmap(df.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Checking correlation of all the independent column with target column in dataset

# %%
plt.figure(figsize=(15,10))
df.corr()['selling_price'].sort_values(ascending=False).drop(['selling_price']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %% [markdown]
# Correlation with another way here some columns are postively correlated and some columns are negatively correlated

# %% [markdown]
# Use zscore method for data loss:

# %%
X=df.drop("selling_price",axis=1)
y=df["selling_price"]

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
new_df=df[(z<3).all(axis=1)]

# %%
new_df.shape
# Out:
# (3673, 12)

# %%
df.shape
# Out:
# (4323, 12)

# %%
Data_loss=((4323-3673)/4323)*100

# %%
Data_loss
# Out:
# 15.03585473051122

# %% [markdown]
# Here 15 persent dataloss using zscore

# %% [markdown]
# Use IQR technique for data loss:

# %%
Q1=df.quantile(0.25)
Q3=df.quantile(0.75)
IQR=Q3-Q1
df_new=df[~((df<(Q1-1.5*IQR))|(df>(Q3+1.5*IQR))).any(axis=1)]

# %%
df_new.shape
# Out:
# (2523, 12)

# %% [markdown]
# Using IQR more dataloss

# %% [markdown]
# Checking skewness:

# %%
df.skew()
# Out:
# selling_price     5.762278
# km_driven        14.598083
# fuel              0.154913
# seller_type      -2.185974
# transmission     -2.932332
# owner             1.563426
# mileage          -0.094528
# engine            1.238668
# max_power         1.815854
# seats             1.932783
# company          -0.245579
# age_of_car        1.017727
# dtype: float64

# %%
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer()
dfpt=pt.fit_transform(df)
df=pd.DataFrame(dfpt,columns=df.columns)

# %%
df.skew()
# Out:
# selling_price    0.000000
# km_driven        0.126062
# fuel             0.022100
# seller_type      1.331589
# transmission    -2.932332
# owner            0.550631
# mileage          0.041675
# engine           0.007879
# max_power        0.142719
# seats           -0.164382
# company         -0.173950
# age_of_car      -0.011878
# dtype: float64

# %%
df['seller_type']=np.log(df['seller_type'])

# %%
df['transmission']=np.log(df['transmission'])

# %% [markdown]
# Use power transform and log transform to remove skewness

# %%
df.skew()
# Out:
# selling_price     0.000000
# km_driven         0.126062
# fuel              0.022100
# seller_type      12.608026
# transmission      0.000000
# owner             0.550631
# mileage           0.041675
# engine            0.007879
# max_power         0.142719
# seats            -0.164382
# company          -0.173950
# age_of_car       -0.011878
# dtype: float64

# %% [markdown]
# After Removing Skewness

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()

# %%
Xd=scaler.fit_transform(X)
X=pd.DataFrame(Xd,columns=X.columns)

# %%
from sklearn.model_selection import train_test_split,cross_val_score

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %% [markdown]
# Importing Library

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=12)

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pred_test=lr.predict(X_test)

# %%
print(r2_score(y_test,pred_test))
# Out:
# 0.6126173286085288

# %%
print(r2_score(y_train,lr.predict(X_train)))
# Out:
# 0.6295987765011557

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.neighbors import KNeighborsRegressor
import warnings
warnings.filterwarnings('ignore')

# %%
parameters={'alpha':[.0001, .001, .01, .1, 1, 10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(X_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 10, 'random_state': 0}

# %%
ls=Lasso(alpha=10,random_state=0)
ls.fit(X_train,y_train)
ls.score(X_train,y_train)
pred_ls=ls.predict(X_test)
lss=r2_score(y_test,pred_ls)
print('R2 score is ',lss)
# Out:
# R2 score is  0.6127074097857844

# %%
cv_score=cross_val_score(ls,X,y,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.5849225972164017

# %% [markdown]
# Use Lasso and check accuracy score and cross validation score

# %%
parameters={'alpha':[1e-15,1e-10,1e-8,1e-5,1e-3,0.1,1,5,10,15,20,30,35,45,50,55,65,100,110,150,1000]}
ri=Ridge()
clf=GridSearchCV(ri,parameters)
clf.fit(X_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 1}

# %%
ri=Ridge(alpha=1)
ri.fit(X_train,y_train)
ri.score(X_train,y_train)
pred_ri=ri.predict(X_test)
rii=r2_score(y_test,pred_ri)
rii
# Out:
# 0.6147713848021625

# %%
cv_score=cross_val_score(ri,X,y,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.594040681159136

# %% [markdown]
# Use Ridge and check accuracy score and cross validation score

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf.fit(X_train,y_train)
rf.score(X_train,y_train)
pred_decision=rf.predict(X_test)

rfs=r2_score(y_test,pred_decision)
print('R2 Score:',rfs*100)
# Out:
# R2 Score: 89.4540725455741

# %%
rfscore=cross_val_score(rf,X,y,cv=5)
rfc=rfscore.mean()
print('cross cal score:',rfs*100)
# Out:
# cross cal score: 89.4540725455741

# %% [markdown]
# Use RandomForestRegressor and check accuracy score and cross validation score

# %%
from sklearn.svm import SVR
sv=SVR()
sv.fit(X_train,y_train)
sv.score(X_train,y_train)
pred_sv=sv.predict(X_test)
svv=r2_score(y_test,pred_sv)
svv
# Out:
# -0.044640465082775416

# %%
svscore=cross_val_score(rf,X,y,cv=5)
sv=svscore.mean()
print('cross cal score:',sv*100)
# Out:
# cross cal score: 85.88494567390515

# %% [markdown]
# Use SVR and check accuracy score and cross validation score

# %%
from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor()
dt.fit(X_train,y_train)
dt.score(X_train,y_train)
pred_dt=dt.predict(X_test)
dtt=r2_score(y_test,pred_dt)
print('R2 score is Test',r2_score(y_test,pred_dt))
# Out:
# R2 score is Test 0.8069023774869604

# %%
dtscore=cross_val_score(dt,X,y,cv=5)
dtc=dtscore.mean()
print('cross cal score:',dtc*100)
# Out:
# cross cal score: 77.37466217414253

# %% [markdown]
# Use DecisionTreeRegressor and check accuracy score and cross validation score

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.naive_bayes import  GaussianNB
from sklearn.neighbors import KNeighborsRegressor

# %%
Ad = AdaBoostRegressor()
Ad.fit(X_train,y_train)
Ad.score(X_train,y_train)
pred_Ad=Ad.predict(X_test)
Add=r2_score(y_test,pred_Ad)
train_score=r2_score(y_train,Ad.predict(X_train))
print('R2 score is Test',r2_score(y_test,pred_Ad))
# Out:
# R2 score is Test 0.4648317435602468

# %%
Adscore=cross_val_score(Ad,X,y,cv=5)
Adc=dtscore.mean()
print('cross cal score:',Adc*100)
# Out:
# cross cal score: 77.37466217414253

# %% [markdown]
# Use AdaBoostRegressor and check accuracy score and cross validation score

# %%
KNN = KNeighborsRegressor()
KNN.fit(X_train,y_train)
KNN.score(X_train,y_train)
pred_KNN=KNN.predict(X_test)
KNNN=r2_score(y_test,pred_KNN)
train_score=r2_score(y_train,KNN.predict(X_train))
print('R2 score is Test',r2_score(y_test,pred_KNN))
# Out:
# R2 score is Test 0.6650841010923765

# %%
KNNscore=cross_val_score(KNN,X,y,cv=5)
KNNc=dtscore.mean()
print('cross cal score:',KNNc*100)
# Out:
# cross cal score: 77.37466217414253

# %% [markdown]
# Use KNeighborsRegressor and check accuracy score and cross validation score

# %% [markdown]
# Here RandomForestRegressor are best and r2 score so apply Hyper parameter tunning on it

# %% [markdown]
# Import GridsearcgCv

# %%
from sklearn.model_selection import GridSearchCV

# %%
import numpy as np

# %%
from sklearn.ensemble import RandomForestRegressor
parameters = {'criterion' : ['mse','mae'],
              'max_features': ["auto","log2"]}

# %% [markdown]
# Import parameters

# %%
GCV=GridSearchCV(RandomForestRegressor(),parameters,cv=5)

# %% [markdown]
# Import GridSearchCV library

# %%
GCV.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                              criterion='mse', max_depth=None,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              max_samples=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators=100, n_jobs=None,
#                                              oob_score=False, random_state=None,
#                                              verbose=0, warm_start=False),
# ...

# %%
GCV.best_params_
# Out:
# {'criterion': 'mae', 'max_features': 'auto'}

# %% [markdown]
# Best parameter list of RandomForestRegressor

# %%
Final_mod2 = RandomForestRegressor(criterion= 'mae',max_features='auto')
Final_mod2.fit(X_train,y_train)
pred = Final_mod2.predict(X_test)
rf=r2_score(y_test,pred_decision)
print(rfc*100)
# Out:
# 85.73085717311967

# %% [markdown]
# Finally print best score

# %%
import joblib
joblib.dump(Final_mod2,'car_price.obj')
# Out:
# ['car_price.obj']

# %%
Final_mod2 = joblib.load('car_price.obj')
pred = Final_mod2.predict(X_test)

predicted_values = pd.DataFrame({'Actual':y_test,'Predicted':pred})

# %%
car_price = joblib.load('car_price.obj')

# %%
prices = car_price.predict(X_train)

# %%
prices
# Out:
# array([ 507940.  ,  463299.99, 1097515.  , ...,  236204.93,  932550.  ,
#         560709.99])

# %%
price_list = pd.DataFrame({'Price':prices})

# %%
price_list
# Out:
#            Price
# 0      507940.00
# 1      463299.99
# 2     1097515.00
# 3      337249.95
# 4      601720.00
# ...          ...
# 3453   362454.99
# 3454   749500.00
# 3455   236204.93
# 3456   932550.00
# 3457   560709.99
#
# [3458 rows x 1 columns]

# %% [markdown]
# Finally creating best model
