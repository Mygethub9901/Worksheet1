# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
import random

# %% [markdown]
# Loading Library

# %%
Data1=pd.read_csv(r'D:\Users\Ankita\Desktop\Data1.csv')

# %% [markdown]
# Loading data

# %% [markdown]
# EDA

# %%
Data1.head()
# Out:
#                             Uniq Id            Crawl Timestamp  \
# 0  0356abfeb71fc1435f32d2df305a56e3  2019-04-09 02:35:01 +0000
# 1  310d723f9a830689d96dd1022d6e895a  2019-04-09 02:35:01 +0000
# 2  35e73855056689f0eac822f150763476  2019-04-09 02:35:01 +0000
# 3  197fcef9053f0549c932c26151224d3e  2019-04-09 02:35:01 +0000
# 4  c7be0650e37aeaf10adc7e0d72242438  2019-04-09 02:35:01 +0000
#
#                                         Product Name  Product Rating  \
# 0  Samsung Galaxy S8 Unlocked 64GB -  Midnight Bl...               4
# 1                                               Oppo               4
# 2  Samsung Galaxy S8 Unlocked 64GB -  Midnight Bl...               4
# 3                                            Camera                4
# 4                                        Dell Laptop               4
#
#                                 Review Title Review Asin  Review Rating  \
# 0                                  One Star   B06Y14T5YW              1
# ...

# %% [markdown]
# Loading the data First 5 rows of dataset

# %%
Data1.shape
# Out:
# (2080, 12)

# %% [markdown]
# there are 2080 rows 12 columns in dataset

# %%
Data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2080 entries, 0 to 2079
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Uniq Id          2080 non-null   object
#  1   Crawl Timestamp  2080 non-null   object
#  2   Product Name     2080 non-null   object
#  3   Product Rating   2080 non-null   int64
#  4   Review Title     2080 non-null   object
#  5   Review Asin      2080 non-null   object
#  6   Review Rating    2080 non-null   int64
#  7   Review Author    2080 non-null   object
#  8   Review Date      2080 non-null   object
#  9   Review Text      2080 non-null   object
#  10  Source           2080 non-null   object
#  11  Product Url      0 non-null      float64
# dtypes: float64(1), int64(2), object(9)
# memory usage: 195.1+ KB

# %% [markdown]
# Describe dataset information in dataset

# %%
Data1.isnull().sum()
# Out:
# Uniq Id               0
# Crawl Timestamp       0
# Product Name          0
# Product Rating        0
# Review Title          0
# Review Asin           0
# Review Rating         0
# Review Author         0
# Review Date           0
# Review Text           0
# Source                0
# Product Url        2080
# dtype: int64

# %% [markdown]
# There are null values was present Product Url column in dataset.

# %%
Data1 = Data1.drop(columns=['Product Url'])

# %% [markdown]
# Drop Product Url column because all null values are present in  this column

# %%
Data1.columns
# Out:
# Index(['Uniq Id', 'Crawl Timestamp', 'Product Name', 'Product Rating',
#        'Review Title', 'Review Asin', 'Review Rating', 'Review Author',
#        'Review Date', 'Review Text', 'Source'],
#       dtype='object')

# %% [markdown]
# Display names of columns in this dataset

# %%
Data1.dtypes
# Out:
# Uniq Id            object
# Crawl Timestamp    object
# Product Name       object
# Product Rating      int64
# Review Title       object
# Review Asin        object
# Review Rating       int64
# Review Author      object
# Review Date        object
# Review Text        object
# Source             object
# dtype: object

# %% [markdown]
# Describe datatypes of all columns in dataset

# %%
Data1.describe()
# Out:
#        Product Rating  Review Rating
# count          2080.0    2080.000000
# mean              4.0       3.826923
# std               0.0       1.652857
# min               4.0       1.000000
# 25%               4.0       2.000000
# 50%               4.0       5.000000
# 75%               4.0       5.000000
# max               4.0       5.000000

# %% [markdown]
# Describe all the information in dataset

# %%
plt.figure(figsize=[12,4])
sns.heatmap(Data1.isnull())
plt.title("Null values")
plt.show()

# %% [markdown]
# Using heatmap shows there was no null values present in this dataset

# %% [markdown]
# Univarient Analysis of dataset:

# %%
sns.countplot(Data1['Uniq Id']);

# %%
plt.figure(figsize=(30,4))
sns.countplot(Data1['Crawl Timestamp']);

# %%
plt.figure(figsize=(25,4))
sns.countplot(Data1['Product Name']);

# %%
sns.countplot(Data1['Product Rating']);

# %%
plt.figure(figsize=(40,4))
sns.countplot(Data1['Review Title']);

# %%
plt.figure(figsize=(10,4))
sns.countplot(Data1['Review Rating']);

# %%
plt.figure(figsize=(5,4))
sns.countplot(Data1['Review Asin']);

# %%
plt.figure(figsize=(35,4))
sns.countplot(Data1['Review Author']);

# %%
plt.figure(figsize=(35,4))
sns.countplot(Data1['Review Date']);

# %%
plt.figure(figsize=(5,4))
sns.countplot(Data1['Source']);

# %% [markdown]
# Checking distribution of columns in dataset:

# %%
sns.histplot(Data1['Uniq Id'],kde=True)
# Out:
# <AxesSubplot:xlabel='Uniq Id', ylabel='Count'>

# %%
plt.figure(figsize=(35,4))
sns.histplot(Data1['Crawl Timestamp'],kde=True)
# Out:
# <AxesSubplot:xlabel='Crawl Timestamp', ylabel='Count'>

# %%
plt.figure(figsize=(25,4))
sns.histplot(Data1['Product Name'],kde=True)
# Out:
# <AxesSubplot:xlabel='Product Name', ylabel='Count'>

# %%
plt.figure(figsize=(5,4))
sns.histplot(Data1['Product Rating'],kde=True)
# Out:
# <AxesSubplot:xlabel='Product Rating', ylabel='Count'>

# %%
plt.figure(figsize=(55,8))
sns.histplot(Data1['Review Title'],kde=True)
# Out:
# <AxesSubplot:xlabel='Review Title', ylabel='Count'>

# %%
plt.figure(figsize=(30,8))
sns.histplot(Data1['Review Asin'],kde=True)
# Out:
# <AxesSubplot:xlabel='Review Asin', ylabel='Count'>

# %%
plt.figure(figsize=(20,4))
sns.histplot(Data1['Review Rating'],kde=True)
# Out:
# <AxesSubplot:xlabel='Review Rating', ylabel='Count'>

# %%
plt.figure(figsize=(30,4))
sns.histplot(Data1['Review Author'],kde=True)
# Out:
# <AxesSubplot:xlabel='Review Author', ylabel='Count'>

# %%
plt.figure(figsize=(30,4))
sns.histplot(Data1['Review Date'],kde=True)
# Out:
# <AxesSubplot:xlabel='Review Date', ylabel='Count'>

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
sns.distplot(Data1['Uniq Id'],kde=True)
plt.subplot(1,2,2)
sns.distplot(Data1['Crawl Timestamp'],kde=True)
# Out:
# <AxesSubplot:xlabel='Crawl Timestamp', ylabel='Density'>

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
sns.distplot(Data1['Product Name'],kde=True)
plt.subplot(1,2,2)
sns.distplot(Data1['Review Title'],kde=True)
# Out:
# <AxesSubplot:xlabel='Review Title', ylabel='Density'>

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
sns.distplot(Data1['Review Asin'],kde=True)
plt.subplot(1,2,2)
sns.distplot(Data1['Review Author'],kde=True)
# Out:
# <AxesSubplot:xlabel='Review Author', ylabel='Density'>

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
sns.distplot(Data1['Review Date'],kde=True)
plt.subplot(1,2,2)
sns.distplot(Data1['Review Text'],kde=True)
# Out:
# <AxesSubplot:xlabel='Review Text', ylabel='Density'>

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
sns.distplot(Data1['Source'],kde=True)
# Out:
# <AxesSubplot:xlabel='Source', ylabel='Density'>

# %% [markdown]
# Here some columns are normally distributed and some columns are not distributed

# %% [markdown]
# Checking Outliers:

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
sns.boxplot(Data1['Uniq Id'])
# Out:
# <AxesSubplot:xlabel='Uniq Id'>

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
sns.boxplot(Data1['Crawl Timestamp'])
# Out:
# <AxesSubplot:xlabel='Crawl Timestamp'>

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
sns.boxplot(Data1['Product Name'])
# Out:
# <AxesSubplot:xlabel='Product Name'>

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
sns.boxplot(Data1['Review Title'])
# Out:
# <AxesSubplot:xlabel='Review Title'>

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
sns.boxplot(Data1['Review Asin'])
# Out:
# <AxesSubplot:xlabel='Review Asin'>

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
sns.boxplot(Data1['Review Author'])
# Out:
# <AxesSubplot:xlabel='Review Author'>

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
sns.boxplot(Data1['Review Date'])
# Out:
# <AxesSubplot:xlabel='Review Date'>

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
sns.boxplot(Data1['Review Text'])
# Out:
# <AxesSubplot:xlabel='Review Text'>

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
sns.boxplot(Data1['Source'])
# Out:
# <AxesSubplot:xlabel='Source'>

# %% [markdown]
# Here some columns outlier was present

# %% [markdown]
# Bi Varient Analysis:

# %%
plt.figure(figsize=[8,4])
plt.title('Comparision')
sns.scatterplot(Data1["Uniq Id"],Data1["Crawl Timestamp"]);

# %% [markdown]
# Bi varient analysis comparision between two columns

# %%
plt.figure(figsize=[8,4])
plt.title('Comparision')
sns.scatterplot(Data1["Product Name"],Data1["Review Title"]);

# %%
plt.figure(figsize=[8,4])
plt.title('Comparision')
sns.scatterplot(Data1["Review Asin"],Data1["Review Author"]);

# %%
plt.figure(figsize=[8,4])
plt.title('Comparision')
sns.scatterplot(Data1["Review Author"],Data1["Review Date"]);

# %%
plt.figure(figsize=[8,4])
plt.title('Comparision')
sns.scatterplot(Data1["Review Text"],Data1["Source"]);

# %%
plt.figure(figsize=[8,4])
plt.title('Comparision')
sns.scatterplot(Data1["Review Text"],Data1["Review Author"],hue=Data1["Review Rating"]);

# %%
plt.figure(figsize=[8,4])
plt.title('Comparision')
sns.scatterplot(Data1["Crawl Timestamp"],Data1["Product Name"],hue=Data1["Review Rating"]);

# %%
plt.figure(figsize=[8,4])
plt.title('Comparision')
sns.scatterplot(Data1["Review Title"],Data1["Review Asin"],hue=Data1["Review Rating"]);

# %%
plt.figure(figsize=[8,4])
plt.title('Comparision')
sns.scatterplot(Data1["Review Date"],Data1["Review Text"],hue=Data1["Review Rating"]);

# %% [markdown]
# Multi Varient Analysis of the Dataset:

# %%
Data1.hist( bins = 10, figsize = (12,8))
plt.show()

# %% [markdown]
# Pairplot of the dataset

# %%
sns.pairplot(Data1, hue='Review Rating')

# %% [markdown]
# Checking Correlation of the dataset:

# %%
cor=Data1.corr()

# %%
cor
# Out:
#                   Uniq Id  Crawl Timestamp  Product Name  Review Title  \
# Uniq Id          1.000000         0.012412     -0.026897      0.064014
# Crawl Timestamp  0.012412         1.000000      0.333827     -0.074819
# Product Name    -0.026897         0.333827      1.000000     -0.176184
# Review Title     0.064014        -0.074819     -0.176184      1.000000
# Review Asin     -0.047760         0.345182      0.923320     -0.182532
# Review Rating    0.134851         0.169680      0.147697     -0.411014
# Review Author   -0.264662         0.049167      0.028692     -0.055039
# Review Date     -0.160920         0.184558      0.094232      0.008528
# Review Text      0.000166        -0.072772      0.069293      0.152808
#
#                  Review Asin  Review Rating  Review Author  Review Date  \
# Uniq Id            -0.047760       0.134851      -0.264662    -0.160920
# Crawl Timestamp     0.345182       0.169680       0.049167     0.184558
# ...

# %%
Data1 = Data1.drop(columns=['Product Rating'])

# %%
Data1 = Data1.drop(columns=['Source'])

# %%
plt.figure(figsize=(8,6))
sns.heatmap(Data1.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Checking correlation of all the independent column with target column in the dataset

# %%
plt.figure(figsize=(6,2))
Data1.corr()['Review Rating'].sort_values(ascending=False).drop(['Review Rating']).plot(kind='bar',color='c')
plt.xlabel('Feature',fontsize=14)
plt.ylabel('column with target names',fontsize=14)
plt.title('correlation',fontsize=18)
plt.show()

# %% [markdown]
# Correlation in different way in the dataset

# %% [markdown]
# Encoding Technique:

# %%
from sklearn.preprocessing import OrdinalEncoder
o=OrdinalEncoder()

# %%
for i in Data1.columns:
    if Data1[i].dtypes=='O' and i!='Churn':
        Data1[i]=o.fit_transform(Data1[i].values.reshape(-1,1))

# %%
Data1.dtypes
# Out:
# Uniq Id            float64
# Crawl Timestamp    float64
# Product Name       float64
# Review Title       float64
# Review Asin        float64
# Review Rating        int64
# Review Author      float64
# Review Date        float64
# Review Text        float64
# dtype: object

# %%
Data1.head()
# Out:
#    Uniq Id  Crawl Timestamp  Product Name  Review Title  Review Asin  \
# 0      1.0              1.0           5.0          37.0          0.0
# 1     19.0              1.0           4.0          62.0          0.0
# 2     22.0              1.0           5.0          16.0          0.0
# 3     12.0              1.0           0.0          52.0          0.0
# 4     81.0              1.0           2.0           8.0          0.0
#
#    Review Rating  Review Author  Review Date  Review Text
# 0              1            0.0         32.0         60.0
# 1              4           80.0         35.0         96.0
# 2              5            9.0         34.0          3.0
# 3              3           40.0          7.0         98.0
# 4              1           62.0         46.0         42.0

# %% [markdown]
# Using Ordinal encoder categorical column converted into numeric

# %%
X=Data1.drop("Review Rating",axis=1)
y=Data1["Review Rating"]

# %% [markdown]
# Use zscore method for data loss for the Dataset:

# %%
from scipy.stats import zscore
z=np.abs(zscore(Data1))
new_df=Data1[(z<3).all(axis=1)]

# %%
new_df.shape
# Out:
# (2075, 9)

# %%
Data1.shape
# Out:
# (2080, 9)

# %%
Data_loss=((2080-2075)/2080)*100

# %%
Data_loss
# Out:
# 0.2403846153846154

# %% [markdown]
# Here 0.24 persent dataloss using zscore in this dataset

# %%
Q1=Data1.quantile(0.25)
Q3=Data1.quantile(0.75)
IQR=Q3-Q1
df_new=Data1[~((Data1<(Q1-1.5*IQR))|(Data1>(Q3+1.5*IQR))).any(axis=1)]

# %%
df_new.shape
# Out:
# (1654, 9)

# %% [markdown]
# Here more dataloss using zscore in this dataset

# %% [markdown]
# Checking Skewness:

# %%
Data1.skew()
# Out:
# Uniq Id           -0.002058
# Crawl Timestamp   -0.017726
# Product Name      -0.268869
# Review Title       0.453523
# Review Asin        1.486129
# Review Rating     -0.907605
# Review Author      0.136605
# Review Date        0.032291
# Review Text        0.010000
# dtype: float64

# %%
from sklearn.preprocessing import PowerTransformer
pt=PowerTransformer()
Data1pt=pt.fit_transform(Data1)
Data1=pd.DataFrame(Data1pt,columns=Data1.columns)

# %%
import numpy as np
Data1['Review Asin']=np.log(Data1['Review Asin'])

# %%
Data1.skew()
# Out:
# Uniq Id           -0.259270
# Crawl Timestamp   -0.214032
# Product Name       0.437494
# Review Title      -0.086754
# Review Asin        0.000000
# Review Rating     -0.729529
# Review Author     -0.273304
# Review Date       -0.268038
# Review Text       -0.269239
# dtype: float64

# %% [markdown]
# Use powertransform and log traonsformer to remove skewness in dataset

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()

# %%
Xd=scaler.fit_transform(X)
X=pd.DataFrame(Xd,columns=X.columns)

# %%
from sklearn.model_selection import train_test_split,cross_val_score

# %%
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %% [markdown]
# Importing libraryies

# %% [markdown]
# Use different models to select best accracy score and select best model.

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=12)

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
pred_test=lr.predict(X_test)

# %%
print(r2_score(y_test,pred_test))
# Out:
# 0.28661383148380204

# %%
print(r2_score(y_train,lr.predict(X_train)))
# Out:
# 0.3057979314541497

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import Ridge
from sklearn.linear_model import Lasso
from sklearn.neighbors import KNeighborsRegressor
import warnings
warnings.filterwarnings('ignore')

# %%
parameters={'alpha':[.0001, .001, .01, .1, 1, 10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(X_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 0.001, 'random_state': 0}

# %%
ls=Lasso(alpha=10,random_state=0)
ls.fit(X_train,y_train)
ls.score(X_train,y_train)
pred_ls=ls.predict(X_test)
lss=r2_score(y_test,pred_ls)
print('R2 score is ',lss)
# Out:
# R2 score is  -0.0020091935553558926

# %%
cv_score=cross_val_score(ls,X,y,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# -0.0005645936022480313

# %% [markdown]
# Use Lasso Regressor r2 score and cross validation score

# %%
parameters={'alpha':[1e-15,1e-10,1e-8,1e-5,1e-3,0.1,1,5,10,15,20,30,35,45,50,55,65,100,110,150,1000]}
ri=Ridge()
clf=GridSearchCV(ri,parameters)
clf.fit(X_train,y_train)
print(clf.best_params_)
# Out:
# {'alpha': 1}

# %%
ri=Ridge(alpha=1)
ri.fit(X_train,y_train)
ri.score(X_train,y_train)
pred_ri=ri.predict(X_test)
rii=r2_score(y_test,pred_ri)
rii
# Out:
# 0.2862749743331172

# %%
cv_score=cross_val_score(ri,X,y,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.30245429778263627

# %% [markdown]
# Use Ridge Regressor r2 score and cross validation score

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf.fit(X_train,y_train)
rf.score(X_train,y_train)
pred_decision=rf.predict(X_test)
rfs=r2_score(y_test,pred_decision)
print('R2 Score:',rfs*100)
# Out:
# R2 score is Test 1.0

# %%
rfscore=cross_val_score(rf,X,y,cv=5)
rfc=rfscore.mean()
print('cross cal score:',rfc*100)
# Out:
# cross cal score: 99.83489027702626

# %% [markdown]
# Use RandomForestRegressor r2 score and cross validation score

# %%
from sklearn.svm import SVR
sv=SVR()
sv.fit(X_train,y_train)
sv.score(X_train,y_train)
pred_sv=sv.predict(X_test)
svv=r2_score(y_test,pred_sv)
svv
# Out:
# 0.7726643480858377

# %%
svscore=cross_val_score(sv,X,y,cv=5)
svc=svscore.mean()
print('cross cal score:',svc*100)
# Out:
# cross cal score: 80.90506339344718

# %% [markdown]
# Use SVR Regressor r2 score and cross validation score

# %%
from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor()
dt.fit(X_train,y_train)
dt.score(X_train,y_train)
pred_dt=dt.predict(X_test)
dtt=r2_score(y_test,pred_dt)
print('R2 score is Test',r2_score(y_test,pred_dt))
# Out:
# R2 score is Test 1.0

# %%
dtscore=cross_val_score(dt,X,y,cv=5)
dtc=dtscore.mean()
print('cross cal score:',dtc*100)
# Out:
# cross cal score: 99.72172924205083

# %% [markdown]
# Use DecisionTreeRegressor r2 score and cross validation score

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.naive_bayes import  GaussianNB
from sklearn.neighbors import KNeighborsRegressor

# %%
from sklearn.ensemble import AdaBoostRegressor
Ad = AdaBoostRegressor()
Ad.fit(X_train,y_train)
Ad.score(X_train,y_train)
pred_Ad=Ad.predict(X_test)
Add=r2_score(y_test,pred_Ad)
train_score=r2_score(y_train,Ad.predict(X_train))
print('R2 score is Test',r2_score(y_test,pred_Ad))
# Out:
# R2 score is Test 0.7930443102386474

# %%
Adscore=cross_val_score(Ad,X,y,cv=5)
Adc=dtscore.mean()
print('cross cal score:',Adc*100)
# Out:
# cross cal score: 99.72172924205083

# %% [markdown]
# Use AdaBoostRegressor r2 score and cross validation score

# %%
from sklearn.neighbors import KNeighborsRegressor
KNN = KNeighborsRegressor()
KNN.fit(X_train,y_train)
KNN.score(X_train,y_train)
pred_KNN=KNN.predict(X_test)
KNNN=r2_score(y_test,pred_KNN)
train_score=r2_score(y_train,KNN.predict(X_train))
print('R2 score is Test',r2_score(y_test,pred_KNN))
# Out:
# R2 score is Test 1.0

# %%
KNNscore=cross_val_score(KNN,X,y,cv=5)
KNNc=dtscore.mean()
print('cross cal score:',KNNc*100)
# Out:
# cross cal score: 99.72172924205083

# %% [markdown]
# Use KNN Regressor r2 score and cross validation score

# %% [markdown]
# Here RandomForestRegressor are best and high r2 score so apply Hyper parameter tunning on it

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# Import GridsearcgCv

# %%
import numpy as np

# %%
from sklearn.ensemble import RandomForestRegressor
parameters = {'n_estimators': [200,700],
                'max_features': ['auto','sqrt'],
                 'max_depth': [4,5]}

# %% [markdown]
# Import parameters

# %%
GCV=GridSearchCV(RandomForestRegressor(),parameters,cv=5)

# %% [markdown]
# Import GridSearchCV library

# %%
GCV.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, error_score=nan,
#              estimator=RandomForestRegressor(bootstrap=True, ccp_alpha=0.0,
#                                              criterion='mse', max_depth=None,
#                                              max_features='auto',
#                                              max_leaf_nodes=None,
#                                              max_samples=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators=100, n_jobs=None,
#                                              oob_score=False, random_state=None,
#                                              verbose=0, warm_start=False),
# ...

# %%
GCV.best_params_
# Out:
# {'max_depth': 5, 'max_features': 'auto', 'n_estimators': 700}

# %% [markdown]
# Best parameter list of RandomForestRegressor

# %%
Final_mod2 = RandomForestRegressor(criterion= 'mae',max_features='auto')
Final_mod2.fit(X_train,y_train)
pred = Final_mod2.predict(X_test)
rf=r2_score(y_test,pred_decision)
print(rfs*100)
# Out:
# 99.9999657646277

# %%
import joblib
joblib.dump(Final_mod2,'Rating.obj')
# Out:
# ['Rating.obj']

# %%
Final_mod2 = joblib.load('Rating.obj')
pred = Final_mod2.predict(X_test)
predicted_values = pd.DataFrame({'Actual':y_test,'Predicted':pred})

# %% [markdown]
# Finally print best score

# %%
Rating = joblib.load('Rating.obj')

# %%
Rating_Status = Rating.predict(X_train)

# %%
Rating_Status
# Out:
# array([5.  , 2.96, 5.  , ..., 5.  , 5.  , 1.  ])

# %% [markdown]
# Finally creating best model
